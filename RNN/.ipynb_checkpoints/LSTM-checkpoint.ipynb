# %%
import os
import csv
import time
import datetime
import random
import json
from collections import Counter
from math import sqrt
import gensim
import pandas as pd
import numpy as np
import tensorflow as tf


from tensorflow.keras.layers import Input,Conv2D,MaxPool2D,concatenate,Flatten,Dense,Dropout,Embedding,Reshape,LSTM
from tensorflow.keras import Sequential,optimizers,losses
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score
from bs4 import BeautifulSoup
import logging
import gensim
from gensim.models import word2vec
from gensim.models.word2vec import Word2Vec

import multiprocessing
import yaml
import jieba

# %% [markdown]
# # 参数配置

# %%
#训练参数
class TrainingConfig(object):
    epoches = 5
    evaluateEvery = 100
    checkpointEvery = 100
    learningRate = 0.01

    
#模型参数
class ModelConfig(object):
    
    #生成嵌入词向量的维度
    embeddingSize = 110
    
    #卷积核数
    numFilters = 50
    

    dropoutKeepProb = 0.5
    
    #L2正则系数
    l2RegLambda = 0.01
    
    
    
class Config(object):
    
    #统一输入文本序列的定长，取了所有序列长度的均值。超出将被截断，不足则补0
    sequenceLength = 200  
    batchSize=64
    epochs=10
    
    #分词后保留大于等于最低词频的词
    miniFreq=1
    
    #数据集路径
    dataSource = "../data/goods_zh.txt"
    stopWordSource = "../data/stopword.txt"
    
    numClasses = 2
    #训练集的比例
    rate = 0.8  
    
    training = TrainingConfig()
    model = ModelConfig()

    
# 实例化配置参数对象
config = Config()

# %%
config.batchSize
# Out:
# 128

# %% [markdown]
# # 预训练词向量

# %%
# 设置输出日志
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

file = open("../data/goods_zh.txt") 
sentences=[]
for line in file:
    temp=line.replace('\n','').split(',,')
    sentences.append(jieba.lcut(temp[0]))
file.close()


model = word2vec.Word2Vec(sentences,size=110,
                     min_count=1,
                     window=10,
                     workers=multiprocessing.cpu_count(),sg=1,
                     iter=20)
model.save('../data/word2VecModel_v3')
# Out:
# W0506 14:14:48.075215 140735550804864 base_any2vec.py:723] consider setting layer size to a multiple of 4 for greater performance

# %%
model = gensim.models.Word2Vec.load('../data/word2VecModel')
model.wv.vocab.keys()
# Out:
# dict_keys(['才', '用', '就', '发现', '相机', '打开', '迟钝', '，', '半天', '反应', '不', '过来', '有时候', '还会卡', '出去', '他们', '又', '给', '解决方案', '。', '还', '没', '穿', '二天', '起毛', '了', '坑', '呢', '！', '我', '怎样', '将', '双卡', '和', '内存卡', '一起', '装进去', '吗', '？', '如果', '不能', '说', '什么', '支持', 'SD', '?', '-', '诺基亚', '手机', '做工', '质量', '太', '差', '后壳', '垃圾', '没用', '几天', '掉', '漆', '为', '毛要', '金属', '材质', '为啥', '不用', '陶瓷', '呀', '我后', '壳', '贴膜', '完', '整体', '的', '感觉', '还是', '不错', '非常', '满意', '京东', '售后服务', '买', '之前', '联系', '客服', '由于', '公司', '新开', '增值税', '发票', '开票', '信息', '出来', '要', '再', '结果', '开', '电子', '换', '电脑', '帐', '裤子', '很', '好', '昨天', '刚买', '保修', '到', '9', '月份', '还有', '一次', '鉴定', '这', '是', '啥', '机子', '冬天', '比较', '保暖', '品质', '保证', '价格', '实惠', '收到', '后', '知道', '怎么', '吧', '从', '下单', '心情', '兴奋', '之后', '糟糕', '透', '东西', '都', '没有', '一部', '一个', '充电器', '连', '百元', '机', '标配', '耳机', '别的', '计较', '太过分', '啊', ' ', '在', '北京', '呆', '3', '天', '动弹', '真', '几把', '慢', '好大', '味道', '放', '三四天', '那个', '味', '去', '不了', '货来', '还行', '两个', '星期', '左右', '便宜', '100', '元', '刚好', '穿着', '凉快', '面料', '身上', '舒服', '夏天', '黑色', '很百搭', '垂感', '也', '搭配', '走起路来', '飘逸', '有', '必须', '个', '好评', '买不到', '三天', '降', '200', '鞋子', '轻便', '值得', '推荐', '衣服', '这个', '值', '一个月', '花屏', '卡死', '屏幕', '闪烁', '&', 'hellip', ';', '老公', '好几个', '特别', '2299', '6G', '+', '64G', '今天', '已经', '降价', '1999', '并且', '优惠券', '第二天', '有人', '1899', '你', '行情', '这么', '客户', '处理', '一直', '拿', '政策', '来', '第二次', '居然', '混乱', '每天', '价', '让', '消费者', '放心', '购买', '入手', '你们', '找', '理论', '一下', '20', '不到', '经常', '卡顿', '触摸', '失灵', '需要', '重新', '锁屏', '才能', '恢复正常', '渣', '拍照', '泛白', '这是', '个例', '情况', '打算', '慎重', '不管', '所谓', '价格战', '真的', '不道德', '不好', '不灵敏', '照相', '清楚', '第一次', '真让人', '失望', '过年', '回家', '送给', '爸爸', '超级', '喜欢', '声音', '很大', '外观', '美', '服务态度', '很差', '而且', '老子', '刚', '买手机', '不行', '断触', '图案', '解锁', '难', '很烦', '因为', '触屏', '游戏', '玩', '流畅', '真心', '太厚', '么', '不是', '尺寸', '合适', '朋友', '祝', '店家', '大卖', '第一', '、', '确实', '全新', '未', '开封', '第二', '设计', '换成', '玻璃', '稍微', '有些', '不同', '但', '手感', '真沉', '几千块', '不戴套', '担心', '所以', '更', '沉', '这要', '重点', '能', '当', '板砖', '第三', '系统', '方面', '就是', '偶尔', '出现', '自动', '失效', '那儿', '亮屏', '*', '第四', '本来', '得', '打个', '四星', '花', '这些', '钱买个', '自己', '打', '脸', '但是', '忒', '坏', '数', '还好', '偏', '降个', '250', '赤裸裸', '讽刺', '二百五', '一星', '哦', '笔记本', '太棒了', '裤型', '特好', '起来', '看着', '方', '总之', '主机', '试用', '过', '评价', '效果', '开机', '十来', '秒', '反应速度', '很快', '网页', '各', '会', '顺畅', '感谢', '热情', '包装', '发货', '给力', '屏幕显示', '一般', '其他', '物流', '一个多月', '花成', '这样', '太气', '人', '618', '超', '意外', '杠杠', '近', '六千', '开个', '酷狗', '浏览器', '360', '卡', '激活', '退', '几年', '购物', '以来', '差评', '愉快', '快递', '小哥', '辛苦', '刚刚', '昨天晚上', '下', '单', '中午', '商家', '图', '一样', '宝贝', '然后', '没什么', '异味', '精美', '性价比', '好看', '夸', '无敌', '投递员', '贴心', '质感', '一流', '女儿', '通过', '争取', '赠', '十分满意', '转换器', '挺舒服', '终于', '对不起', '没商量', '货', '瑕疵', '问题', '自带', '搭理', '两部', '另', '32G', '这款', '前后', '双', '摄像头', '摆设', '不信', '手指头', '挡', '看看', '电池', '耐用', '想', '其它', '华为', '光', '占', '十几个', 'G', '鞋', '款式', '样式', '大小', '昨晚', '迫不及待', '拆开', '四川', '上脚', '我太肥', '蛮', '买贵', '1598', '1500', '被', '骗', '43', '码', '鞋跟', '40', '码鞋', '大', '跟', '他', '沟通', '说话', '高兴', '速度', '龟速', '精细', '物超所值', '亲', '啦', '简单', '大方', '帅气', '赶紧', 'office365', '不太', '友好', '非得', '#', '拿到', '手', '发', '烫得', '厉害', '退货', '事', '到货', '迅速', '店铺', '~', '下次', '还会来', '脚臭', '闻', '网站', '同样', '价位', '啥事', '不知', '是不是', '假货', '问', '却说', '版', '型号', '合身', '买回来', '加', '8g', '内存', '固态', '吃', '鸡', '开强', '冷', '风扇', '带', '可以', '希望', '再用', '评', '别说', '机器', '售后', '三星', '支付', '二维码', '添加', '软件', '反馈', '那边', '工程师', '回复', 'ui', '做', '那么', '牛', '腾出', '一两个', '把', '升', '下级', '十几年', '前', '差不多', '手机电池', '一年', '苹果', '7', '待机时间', '说好', '好礼', '别人', '兑', '剩', '积分', '宣传', '噱头', '如果说', '现在', '的话', '一点', '不想', '没法', '比', '到处', 'bug', '完全', '颠覆', '对', '认知', '费', '大劲', '写', '评论', '大家', '有用', '转安卓', '一定', '一半', '态度', '很多', '这种', '自营', '加盟', '式', '只会', '越做越', '人员素质', '把关', '考核', '评级', '跟不上', '草接', '微信', '老', '挂断', '取消', '差劲', '老爸', '开始', '电话', '进去', '呼', '行', '多少', '半个', '月', '大洋', '任何', '补偿', '绝对', '要死', 'home', '发 ...

# %%
model['酷毙']
# Out:
# /Users/monstar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-fbdd3aa848af> in <module>
# ----> 1 model['酷毙']
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/word2vec.py in __getitem__(self, words)
#    1119
#    1120         """
# -> 1121         return self.wv.__getitem__(words)
#    1122
#    1123     @deprecated("Method will be removed in 4.0.0, use self.wv.__contains__() instead")
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     345         if isinstance(entities, string_types):
#     346             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 347             return self.get_vector(entities)
#     348
#     349         return vstack([self.get_vector(entity) for entity in entities])
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     463
#     464     def get_vector(self, word):
# --> 465         return self.word_vec(word)
#     466
#     467     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     460             return result
#     461         else:
# --> 462             raise KeyError("word '%s' not in vocabulary" % word)
#     463
#     464     def get_vector(self, word):
#
# KeyError: "word '酷毙' not in vocabulary"

# %% [markdown]
# # 数据预处理

# %%
# 数据预处理的类，生成训练集和测试集
class Dataset(object):
    def __init__(self, config):
        self.dataSource = config.dataSource
        self.stopWordSource = config.stopWordSource  
        
        # 每条输入的序列处理为定长
        self.sequenceLength = config.sequenceLength  
        
        self.embeddingSize = config.model.embeddingSize
        self.batchSize = config.batchSize
        self.rate = config.rate
        self.miniFreq=config.miniFreq
        
        self.stopWordDict = {}
        
        self.trainReviews = []
        self.trainLabels = []
        
        self.evalReviews = []
        self.evalLabels = []
        
        self.wordEmbedding =None
        self.n_symbols=0
        
        self.wordToIndex = {}
        self.indexToWord = {}
        
        
        
    def readData(self, filePath):
        file = open(filePath) 
        text=[]
        label=[]
        for line in file:
            temp=line.replace('\n','').split(',,')
            text.append(temp[0])
            label.append(temp[1])
        file.close()
        
        print('data:',len(text),len(label))
        texts = [jieba.lcut(document.replace('\n', '')) for document in text]

        return texts, label

    
    def readStopWord(self, stopWordPath):
        """
        读取停用词
        """
        
        with open(stopWordPath, "r") as f:
            stopWords = f.read()
            stopWordList = stopWords.splitlines()
            # 将停用词用列表的形式生成，之后查找停用词时会比较快
            self.stopWordDict = dict(zip(stopWordList, list(range(len(stopWordList)))))
    
    
    def getWordEmbedding(self, words):
        """
        按照我们的数据集中的单词取出预训练好的word2vec中的词向量
        """
        
        #中文
        model = gensim.models.Word2Vec.load('../data/word2VecModel')
        
        vocab = []
        wordEmbedding = []
        
        # 添加 "pad" 和 "UNK", 
        vocab.append("pad")
        wordEmbedding.append(np.zeros(self.embeddingSize))
        
        vocab.append("UNK")
        wordEmbedding.append(np.random.randn(self.embeddingSize))
        
        for word in words:
            try:
                
                #中文
                vector =model[word]
                
                vocab.append(word)
                wordEmbedding.append(vector)
            except:
                
                print(word + " : 不存在于词向量中")
                
        return vocab, np.array(wordEmbedding)
    
    
    
    def genVocabulary(self, reviews):
        """
        生成词向量和词汇-索引映射字典，可以用全数据集
        """
        
        allWords = [word for review in reviews for word in review]
        
        # 去掉停用词
        subWords = [word for word in allWords if word not in self.stopWordDict]
        
        wordCount = Counter(subWords)  # 统计词频，排序
        sortWordCount = sorted(wordCount.items(), key=lambda x: x[1], reverse=True)
        
        # 去除低频词
        words = [item[0] for item in sortWordCount if item[1] >= self.miniFreq ]
        
        
        #获取词列表和顺序对应的预训练权重矩阵
        vocab, wordEmbedding = self.getWordEmbedding(words)
        
        self.wordEmbedding = wordEmbedding
        
        self.wordToIndex = dict(zip(vocab, list(range(len(vocab)))))
        self.indexToWord = dict(zip(list(range(len(vocab))), vocab))
        self.n_symbols = len(self.wordToIndex) + 1
        
        # 将词汇-索引映射表保存为json数据，之后做inference时直接加载来处理数据
        with open("../data/wordJson/wordToIndex.json", "w", encoding="utf-8") as f:
            json.dump(self.wordToIndex, f)
        
        with open("../data/wordJson/indexToWord.json", "w", encoding="utf-8") as f:
            json.dump(self.indexToWord, f)
            
            
            
            
    
    def reviewProcess(self, review, sequenceLength, wordToIndex):
        """
        将数据集中的每条评论里面的词，根据词表，映射为index表示
        每条评论 用index组成的定长数组来表示
        
        """
        
        reviewVec = np.zeros((sequenceLength))
        sequenceLen = sequenceLength
        
        # 判断当前的序列是否小于定义的固定序列长度
        if len(review) < sequenceLength:
            sequenceLen = len(review)
            
        for i in range(sequenceLen):
            if review[i] in wordToIndex:
                reviewVec[i] = wordToIndex[review[i]]
            else:
                reviewVec[i] = wordToIndex["UNK"]

        return reviewVec

    
    
    
    def genTrainEvalData(self, x, y, rate):
        """
        生成训练集和验证集
        """
        
        reviews = []
        labels = []
        
        # 遍历所有的文本，将文本中的词转换成index表示
        for i in range(len(x)):
            
            reviewVec = self.reviewProcess(x[i], self.sequenceLength, self.wordToIndex)
            reviews.append(reviewVec)
            
            labels.append([y[i]])
            
        trainIndex = int(len(x) * rate)
        
       
        #trainReviews = sequence.pad_sequences(reviews[:trainIndex], maxlen=self.sequenceLength)
        trainReviews = np.asarray(reviews[:trainIndex], dtype="int64")
        trainLabels = np.array(labels[:trainIndex], dtype="float32")
        trainLabels = to_categorical(trainLabels,num_classes=2) 
        
        #evalReviews = sequence.pad_sequences(reviews[trainIndex:], maxlen=self.sequenceLength)
        evalReviews = np.asarray(reviews[trainIndex:], dtype="int64")
        evalLabels = np.array(labels[trainIndex:], dtype="float32")
        evalLabels = to_categorical(evalLabels,num_classes=2) 

        return trainReviews, trainLabels, evalReviews, evalLabels
        
        
        
        
        
 
            
    def dataGen(self):
        """
        初始化训练集和验证集
        """
        
        #读取停用词
        self.readStopWord(self.stopWordSource)
        
        #读取数据集
        reviews, labels = self.readData(self.dataSource)
        
        #分词、去停用词
        #生成 词汇-索引 映射表和预训练权重矩阵，并保存
        self.genVocabulary(reviews)
        
        
        #初始化训练集和测试集
        trainReviews, trainLabels, evalReviews, evalLabels = self.genTrainEvalData(reviews, labels, self.rate)
        self.trainReviews = trainReviews
        self.trainLabels = trainLabels
        
        self.evalReviews = evalReviews
        self.evalLabels = evalLabels
        
        
data = Dataset(config)
data.dataGen()
# Out:
# Building prefix dict from the default dictionary ...
# WARNING: Logging before flag parsing goes to stderr.
# I0507 09:18:09.638988 140735550804864 __init__.py:111] Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/60/2w7_vlcs36d59_tzgd2g3hv40000gn/T/jieba.cache
# I0507 09:18:09.641286 140735550804864 __init__.py:131] Loading model from cache /var/folders/60/2w7_vlcs36d59_tzgd2g3hv40000gn/T/jieba.cache
# data: 101058 101058
# Loading model cost 0.979 seconds.
# I0507 09:18:10.619856 140735550804864 __init__.py:163] Loading model cost 0.979 seconds.
# Prefix dict has been built succesfully.
# I0507 09:18:10.621370 140735550804864 __init__.py:164] Prefix dict has been built succesfully.
# /Users/monstar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:81: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# 能教 : 不存在于词向量中
# 漆该 : 不存在于词向量中
# 缓缓 : 不存在于词向量中
# 一声不吭 : 不存在于词向量中
# 发报 : 不存在于词向量中
# 压制 : 不存在于词向量中
# 乱触 : 不存在于词向量中
# 自封 : 不存在于词向量中
# 出口气 : 不存在于词向量中
# 115 : 不存在于词向量中
# 漏放 : 不存在于词向量中
# jiji : 不存在于词向量中
# 四重 : 不存在于词向量中
# N6Pro : 不存在于词向量中
# 相接处 : 不存在于词向量中
# 余枫 : 不存在于词向量中
# 老段 : 不存在于词向量中
# 如火如荼 : 不存在于词向量中
# 键碎 : 不存在于词向量中
# 还算蛮 : 不存在于词向量中
# CPU100% : 不存在于词向量中
# 关完 : 不存在于词向量中
# 星去 : 不存在于词向量中
# 闻多 : 不存在于词向量中
# 工作服 : 不存在于词向量中
# 64hz : 不存在于词向量中
# 叮咛 : 不存在于词向量中
# 姐 : 不存在于词向量中
# 火红 : 不存在于词向量中
# 估 : 不存在于词向量中
# 收只 : 不存在于词向量中
# 下排 : 不存在于词向量中
# 星赞 : 不存在于词向量中
# 脸孔 : 不存在于词向量中
# 卡二槽 : 不存在于词向量中
# 槊 : 不存在于词向量中
# 黄得 : 不存在于词向量中
# 封短信 : 不存在于词向量中
# 几年级 : 不存在于词向量中
# 虎牙 : 不存在于词向量中
# 无原 : 不存在于词向量中
# 闻名 : 不存在于词向量中
# 偏轻 : 不存在于词向量中
# 跳纹 : 不存在于词向量中
# 包醒 : 不存在于词向量中
# 背对着 : 不存在于词向量中
# mxi150 : 不存在于词向量中
# 卡洛驰 : 不存在于词向量中
# 把柄 : 不存在于词向量中
# 420G : 不存在于词向量中
# 并不认为 : 不存在于词向量中
# ntcs : 不存在于词向量中
# 发型 : 不存在于词向量中
# 色彩缤纷 : 不存在于词向量中
# 宽宽的 : 不存在于词向量中
# 麻袋 : 不存在于词向量中
# 模内 : 不存在于词向量中
# 平齐 : 不存在于词向量中
# 防爆 : 不存在于词向量中
# 670 : 不存在于词向量中
# 11.00 : 不存在于词向量中
# 前到 : 不存在于词向量中
# 自占 : 不存在于词向量中
# 1.45 : 不存在于词向量中
# LeMax2 : 不存在于词向量中
# 强塞 : 不存在于词向量中
# 一千六 : 不存在于词向量中
# 工具箱 : 不存在于词向量中
# L66 : 不存在于词向量中
# 含行 : 不存在于词向量中
# 有油点 : 不存在于词向量中
# 变着 : 不存在于词向量中
# 加店 : 不存在于词向量中
# 一个鼻孔 : 不存在于词向量中
# 总一加 : 不存在于词向量中
# 升值 : 不存在于词向量中
# 尊贵 : 不存在于词向量中
# 递过来 : 不存在于词向量中
# 键息 : 不存在于词向量中
# 害得输 : 不存在于词向量中
# 干守 : 不存在于词向量中
# 无礼 : 不存在于词向量中
# 手短星 : 不存在于词向量中
# 录下来 : 不存在于词向量中
# 科室 : 不存在于词向量中
# 歼商 : 不存在于词向量中
# 塑料厂 : 不存在于词向量中
# 撒好 : 不存在于词向量中
# 热是 : 不存在于词向量中
# 一快 : 不存在于词向量中
# 真扣 : 不存在于词向量中
# 手杆 : 不存在于词向量中
# 千奇 : 不存在于词向量中
# 鞋太瘦 : 不存在于词向量中
# uiojklm : 不存在于词向量中
# daye : 不存在于词向量中
# 略低于 : 不存在于词向量中
# 780m : 不存在于词向量中
# 250m : 不存在于词向量中
# 我太图 : 不存在于词向量中
# 中想 : 不存在于词向量中
# pIUS : 不存在于词向量中
# 用戶 : 不存在于词向量中
# 客戶 : 不存在于词向量中
# 就迫 : 不存在于词向量中
# U3.0 : 不存在于词向量中
# 家居用品 : 不存在于词向量中
# 例 : 不存在于词向量中
# 光鲜 : 不存在于词向量中
# 越往 : 不存在于词向量中
# 悄悄 : 不存在于词向量中
# 巨长 : 不存在于词向量中
# 6788 : 不存在于词向量中
# 整俩 : 不存在于词向量中
# m6 : 不存在于词向量中
# 完隔 : 不存在于词向量中
# 使用寿命 : 不存在于词向量中
# 拆个机 : 不存在于词向量中
# 遗漏 : 不存在于词向量中
# 瘦身 : 不存在于词向量中
# 条薄 : 不存在于词向量中
# 加棉 : 不存在于词向量中
# 沈阳 : 不存在于词向量中
# 南北 : 不存在于词向量中
# 指到 : 不存在于词向量中
# fps130 : 不存在于词向量中
# 成绿 : 不存在于词向量中
# 更薄 : 不存在于词向量中
# 戏本 : 不存在于词向量中
# 价格控制 : 不存在于词向量中
# 用度 : 不存在于词向量中
# 小肚 : 不存在于词向量中
# 肚 : 不存在于词向量中
# 慢不吹 : 不存在于词向量中
# 非你莫属 : 不存在于词向量中
# 费尽周折 : 不存在于词向量中
# 券用 : 不存在于词向量中
# 做何 : 不存在于词向量中
# 泡菜 : 不存在于词向量中
# jhd : 不存在于词向量中
# 从始 : 不存在于词向量中
# 上传下载 : 不存在于词向量中
# 购票 : 不存在于词向量中
# 进站 : 不存在于词向量中
# 刷不出 : 不存在于词向量中
# 骑个 : 不存在于词向量中
# 货成 : 不存在于词向量中
# 太宽收 : 不存在于词向量中
# 网钱 : 不存在于词向量中
# 1750 : 不存在于词向量中
# 有多烂 : 不存在于词向量中
# 家有 : 不存在于词向量中
# 常棒 : 不存在于词向量中
# 单烤 : 不存在于词向量中
# FPU : 不存在于词向量中
# 45W : 不存在于词向量中
# 漆掉 : 不存在于词向量中
# 地刚 : 不存在于词向量中
# 连验机 : 不存在于词向量中
# 初用 : 不存在于词向量中
# 小如 : 不存在于词向量中
# 小勇 : 不存在于词向量中
# 盘装 : 不存在于词向量中
# 黑顶配 : 不存在于词向量中
# 网别 : 不存在于词向量中
# 相见 : 不存在于词向量中
# 小白用 : 不存在于词向量中
# 最顶配 : 不存在于词向量中
# 49g : 不存在于词向量中
# 防御 : 不存在于词向量中
# baichi : 不存在于词向量中
# zheng : 不存在于词向量中
# 但膜 : 不存在于词向量中
# 真蛮 : 不存在于词向量中
# 整容 : 不存在于词向量中
# 原画 : 不存在于词向量中
# 瘦脚 : 不存在于词向量中
# 看头 : 不存在于词向量中
# 必输 : 不存在于词向量中
# 菲利普 : 不存在于词向量中
# 比高下 : 不存在于词向量中
# 和畅 : 不存在于词向量中
# 摄坏 : 不存在于词向量中
# 我行我素 : 不存在于词向量中
# 勃艮第 : 不存在于词向量中
# 开厢货 : 不存在于词向量中
# 开火 : 不存在于词向量中
# 体测 : 不存在于词向量中
# 代了 : 不存在于词向量中
# 换真 : 不存在于词向量中
# 饮 : 不存在于词向量中
# 咿咿呀呀 : 不存在于词向量中
# 真急 : 不存在于词向量中
# 深意 : 不存在于词向量中
# 到来之际 : 不存在于词向量中
# 融洽 : 不存在于词向量中
# 内帮 : 不存在于词向量中
# 好言好语 : 不存在于词向量中
# 无音 : 不存在于词向量中
# 活用 : 不存在于词向量中
# 焦头烂额 : 不存在于词向量中
# 特快专递 : 不存在于词向量中
# 保证书 : 不存在于词向量中
# 高高挂起 : 不存在于词向量中
# 晒个 : 不存在于词向量中
# 差事 : 不存在于词向量中
# 订货人 : 不存在于词向量中
# 真要命 : 不存在于词向量中
# っ : 不存在于词向量中
# 店取 : 不存在于词向量中
# 取经 : 不存在于词向量中
# 全皮 : 不存在于词向量中
# 国服 : 不存在于词向量中
# 回主 : 不存在于词向量中
# 让出 : 不存在于词向量中
# 单帮 : 不存在于词向量中
# 摔跤 : 不存在于词向量中
# 义无反顾 : 不存在于词向量中
# 问是 : 不存在于词向量中
# 避过 : 不存在于词向量中
# 因买 : 不存在于词向量中
# 乱整 : 不存在于词向量中
# 简练 : 不存在于词向量中
# 得息屏 : 不存在于词向量中
# 分会 : 不存在于词向量中
# 深海 : 不存在于词向量中
# 泰坦 : 不存在于词向量中
# 封死 : 不存在于词向量中
# 扣开 : 不存在于词向量中
# 线断 : 不存在于词向量中
# 再线 : 不存在于词向量中
# 特仑苏 : 不存在于词向量中
# 特能 : 不存在于词向量中
# 转刚 : 不存在于词向量中
# 傍着 : 不存在于词向量中
# 换贵 : 不存在于词向量中
# 耐下 : 不存在于词向量中
# 音筒 : 不存在于词向量中
# 他发 : 不存在于词向量中
# 返不返 : 不存在于词向量中
# 新股 : 不存在于词向量中
# 白杠 : 不存在于词向量中
# 闪白杠 : 不存在于词向量中
# 对接 : 不存在于词向量中
# 推委 : 不存在于词向量中
# 2017.01 : 不存在于词向量中
# 捕捉到 : 不存在于词向量中
# 陶醉 : 不存在于词向量中
# 噪响 : 不存在于词向量中
# 蛟龙 : 不存在于词向量中
# 可握 : 不存在于词向量中
# 宝级 : 不存在于词向量中
# 非原 : 不存在于词向量中
# 关乎 : 不存在于词向量中
# 开关电源 : 不存在于词向量中
# 端子 : 不存在于词向量中
# 烧红 : 不存在于词向量中
# 不打紧 : 不存在于词向量中
# 相距甚远 : 不存在于词向量中
# 推三挡 : 不存在于词向量中
# 不免有些 : 不存在于词向量中
# 太阳镜 : 不存在于词向量中
# 发涩 : 不存在于词向量中
# 嘴上 : 不存在于词向量中
# 烧瓶 : 不存在于词向量中
# 巡航 : 不存在于词向量中
# 无中生有 : 不存在于词向量中
# 毒奶粉 : 不存在于词向量中
# 仙剑 : 不存在于词向量中
# 小跑 : 不存在于词向量中
# 一久 : 不存在于词向量中
# 贡 : 不存在于词向量中
# 勤俭 : 不存在于词向量中
# 之久 : 不存在于词向量中
# 试验机 : 不存在于词向量中
# 73% : 不存在于词向量中
# vivoZ1 : 不存在于词向量中
# 没人答 : 不存在于词向量中
# 忘买 : 不存在于词向量中
# vio : 不存在于词向量中
# 键连电 : 不存在于词向量中
# 这破牌 : 不存在于词向量中
# 老铁要 : 不存在于词向量中
# 破锣音 : 不存在于词向量中
# 必需 : 不存在于词向量中
# 会修 : 不存在于词向量中
# 最出色 : 不存在于词向量中
# 拿坏 : 不存在于词向量中
# 碰碎 : 不存在于词向量中
# 过高后 : 不存在于词向量中
# 洗出来 : 不存在于词向量中
# 水个 : 不存在于词向量中
# 赞好 : 不存在于词向量中
# 某克 : 不存在于词向量中
# 达斯 : 不存在于词向量中
# 37w : 不存在于词向量中
# 发指 : 不存在于词向量中
# 行用 : 不存在于词向量中
# 没得安卓 : 不存在于词向量中
# 现品 : 不存在于词向量中
# 生命财产 : 不存在于词向量中
# 交接处 : 不存在于词向量中
# 盒封 : 不存在于词向量中
# 签贴 : 不存在于词向量中
# 玩逆战 : 不存在于词向量中
# 找刷 : 不存在于词向量中
# 手刷 : 不存在于词向量中
# 大礼 : 不存在于词向量中
# 不太符 : 不存在于词向量中
# 拉直 : 不存在于词向量中
# 黑水 : 不存在于词向量中
# 家离 : 不存在于词向量中
# 五评 : 不存在于词向量中
# 实买实 : 不存在于词向量中
# 买友 : 不存在于词向量中
# 留学生 : 不存在于词向量中
# 整流器 : 不存在于词向量中
# 上带 : 不存在于词向量中
# 吃瓜 : 不存在于词向量中
# 煽风点火 : 不存在于词向量中
# 判断能力 : 不存在于词向量中
# 道听途说 : 不存在于词向量中
# 不能自拔 : 不存在于词向量中
# 日达 : 不存在于词向量中
# 捣乱 : 不存在于词向量中
# 加赠 : 不存在于词向量中
# 慢边 : 不存在于词向量中
# 尖头 : 不存在于词向量中
# 850M : 不存在于词向量中
# eMMc : 不存在于词向量中
# 偏小换 : 不存在于词向量中
# 建义 : 不存在于词向量中
# 小味 : 不存在于词向量中
# 能调 : 不存在于词向量中
# 游击战 : 不存在于词向量中
# 黑域 : 不存在于词向量中
# camera : 不存在于词向量中
# port : 不存在于词向量中
# 栏锁 : 不存在于词向量中
# 同门 : 不存在于词向量中
# PU : 不存在于词向量中
# 卷减 : 不存在于词向量中
# 冻坏 : 不存在于词向量中
# 早踏 : 不存在于词向量中
# 连防 : 不存在于词向量中
# 改错 : 不存在于词向量中
# 蠢得 : 不存在于词向量中
# 铭 : 不存在于词向量中
# 瑄 : 不存在于词向量中
# 实况足球 : 不存在于词向量中
# 赁 : 不存在于词向量中
# 精进 : 不存在于词向量中
# 没盖 : 不存在于词向量中
# 似有 : 不存在于词向量中
# 分验 : 不存在于词向量中
# 泉 : 不存在于词向量中
# 要厚 : 不存在于词向量中
# CD : 不存在于词向量中
# 附膜 : 不存在于词向量中
# 没选真 : 不存在于词向量中
# matebookX : 不存在于词向量中
# 金没货 : 不存在于词向量中
# 废材 : 不存在于词向量中
# 包碎 : 不存在于词向量中
# 麦联 : 不存在于词向量中
# 耐久度 : 不存在于词向量中
# 惯用 : 不存在于词向量中
# 档案 : 不存在于词向量中
# 账全 : 不存在于词向量中
# 系运存 : 不存在于词向量中
# 言过其实 : 不存在于词向量中
# 或云 : 不存在于词向量中
# 栏字 : 不存在于词向量中
# 全调 : 不存在于词向量中
# 大才行 : 不存在于词向量中
# 术 : 不存在于词向量中
# 可够 : 不存在于词向量中
# 300w : 不存在于词向量中
# 不辱使命 : 不存在于词向量中
# 兢兢业业 : 不存在于词向量中
# 那号 : 不存在于词向量中
# 三瓜 : 不存在于词向量中
# 两枣 : 不存在于词向量中
# 小乔 : 不存在于词向量中
# 玛瑙 : 不存在于词向量中
# 发贸快 : 不存在于词向量中
# 运送费 : 不存在于词向量中
# 玛德算 : 不存在于词向量中
# 才响 : 不存在于词向量中
# 套进去 : 不存在于词向量中
# 节前 : 不存在于词向量中
# 撇开 : 不存在于词向量中
# ▄ : 不存在于词向量中
# 油漆味 : 不存在于词向量中
# 曹是 : 不存在于词向量中
# 糖 : 不存在于词向量中
# 可得 : 不存在于词向量中
# 保质保量 : 不存在于词向量中
# 未刷机 : 不存在于词向量中
# 冬裤 : 不存在于词向量中
# 比爱步 : 不存在于词向量中
# 拖网 : 不存在于词向量中
# 划掉 : 不存在于词向量中
# 越开 : 不存在于词向量中
# 起热太快 : 不存在于词向量中
# 某普 : 不存在于词向量中
# 比某 : 不存在于词向量中
# 为耀 : 不存在于词向量中
# 1.12 : 不存在于词向量中
# 出窄 : 不存在于词向量中
# 红里 : 不存在于词向量中
# 5sp : 不存在于词向量中
# 标定 : 不存在于词向量中
# 试码 : 不存在于词向量中
# 绒布 : 不存在于词向量中
# 问卖 : 不存在于词向量中
# 这抗 : 不存在于词向量中
# 阎王 : 不存在于词向量中
# 热弯膜 : 不存在于词向量中
# 超级终端 : 不存在于词向量中
# H28U74303AMR : 不存在于词向量中
# 屏微曲 : 不存在于词向量中
# 老罗白 : 不存在于词向量中
# 二十五块 : 不存在于词向量中
# 中贞 : 不存在于词向量中
# 真实感 : 不存在于词向量中
# 负费 : 不存在于词向量中
# 360F5 : 不存在于词向量中
# 六折 : 不存在于词向量中
# expolrer : 不存在于词向量中
# 暗号 : 不存在于词向量中
# 76744657419 : 不存在于词向量中
# 一个套 : 不存在于词向量中
# 这烂膜 : 不存在于词向量中
# 小狗狗 : 不存在于词向量中
# 六刚 : 不存在于词向量中
# 抽出 : 不存在于词向量中
# 阳逻 : 不存在于词向量中
# 打顺 : 不存在于词向量中
# 丰问 : 不存在于词向量中
# 成拉鸡 : 不存在于词向量中
# 这堆 : 不存在于词向量中
# 时卡成 : 不存在于词向量中
# 家哈 : 不存在于词向量中
# 座 : 不存在于词向量中
# 小山 : 不存在于词向量中
# 高耸入云 : 不存在于词向量中
# 女盆友 : 不存在于词向量中
# vo6 : 不存在于词向量中
# 小而 : 不存在于词向量中
# 夜视 : 不存在于词向量中
# 买匹克 : 不存在于词向量中
# 报案 : 不存在于词向量中
# 已扁 : 不存在于词向量中
# 暗蓝色 : 不存在于词向量中
# 浅紫色 : 不存在于词向量中
# 村款 : 不存在于词向量中
# 气量 : 不存在于词向量中
# 下想 : 不存在于词向量中
# 别太 : 不存在于词向量中
# 申 : 不存在于词向量中
# 框点 : 不存在于词向量中
# 煞 : 不存在于词向量中
# 加光区 : 不存在于词向量中
# 挤牙膏 : 不存在于词向量中
# 回首 : 不存在于词向量中
# 望见 : 不存在于词向量中
# 故乡 : 不存在于词向量中
# 月亮 : 不存在于词向量中
# 一阵儿 : 不存在于词向量中
# 真破 : 不存在于词向量中
# 实而 : 不存在于词向量中
# 他争 : 不存在于词向量中
# 品来 : 不存在于词向量中
# 贵得 : 不存在于词向量中
# 说合 : 不存在于词向量中
# 电天 : 不存在于词向量中
# 黑皮 : 不存在于词向量中
# 你力 : 不存在于词向量中
# 11.5 : 不存在于词向量中
# V97 : 不存在于词向量中
# ar : 不存在于词向量中
# 偏蓝 : 不存在于词向量中
# 密码箱 : 不存在于词向量中
# 照常 : 不存在于词向量中
# 鱿 : 不存在于词向量中
# 搞掉 : 不存在于词向量中
# 工程部 : 不存在于词向量中
# CAD2016 : 不存在于词向量中
# 天正 : 不存在于词向量中
# 用卡针 : 不存在于词向量中
# 好令 : 不存在于词向量中
# 挺蛮 : 不存在于词向量中
# 风道 : 不存在于词向量中
# boom : 不存在于词向量中
# 拉高 : 不存在于词向量中
# 开侧 : 不存在于词向量中
# 先卡顿 : 不存在于词向量中
# 50W : 不存在于词向量中
# 你关 : 不存在于词向量中
# 那回 : 不存在于词向量中
# 一兆多 : 不存在于词向量中
# 穿山 : 不存在于词向量中
# ie : 不存在于词向量中
# 已爆 : 不存在于词向量中
# 跑步机 : 不存在于词向量中
# 发射台 : 不存在于词向量中
# 当一 : 不存在于词向量中
# 意然 : 不存在于词向量中
# r7s : 不存在于词向量中
# nave : 不存在于词向量中
# 字面 : 不存在于词向量中
# 库子 : 不存在于词向量中
# 国际标准 : 不存在于词向量中
# 弧边 : 不存在于词向量中
# 累心 : 不存在于词向量中
# 洗手 : 不存在于词向量中
# 口中 : 不存在于词向量中
# 好料 : 不存在于词向量中
# 认真仔细 : 不存在于词向量中
# 斟酌一下 : 不存在于词向量中
# 第十五天 : 不存在于词向量中
# 借到 : 不存在于词向量中
# 七八点 : 不存在于词向量中
# 成白块 : 不存在于词向量中
# 打块 : 不存在于词向量中
# command : 不存在于词向量中
# 靠前 : 不存在于词向量中
# 有多水 : 不存在于词向量中
# 背景图 : 不存在于词向量中
# 配线 : 不存在于词向量中
# 信服 : 不存在于词向量中
# 只会响 : 不存在于词向量中
# 433m : 不存在于词向量中
# 绝口不提 : 不存在于词向量中
# 要部 : 不存在于词向量中
# 钢板 : 不存在于词向量中
# 擦份 : 不存在于词向量中
# 人累 : 不存在于词向量中
# 红光 : 不存在于词向量中
# 万刚 : 不存在于词向量中
# sketch : 不存在于词向量中
# 十分之一 : 不存在于词向量中
# 不知所措 : 不存在于词向量中
# 航行 : 不存在于词向量中
# 整错 : 不存在于词向量中
# 整差评 : 不存在于词向量中
# 妙招 : 不存在于词向量中
# 吸吸 : 不存在于词向量中
# 长筒靴 : 不存在于词向量中
# 长筒 : 不存在于词向量中
# 立竿见影 : 不存在于词向量中
# 吸完 : 不存在于词向量中
# 换家店 : 不存在于词向量中
# 赞哈 : 不存在于词向量中
# 待定 : 不存在于词向量中
# 铃响 : 不存在于词向量中
# 忙慢 : 不存在于词向量中
# 漂浮物 : 不存在于词向量中
# 这一晚 : 不存在于词向量中
# 评判 : 不存在于词向量中
# 廋 : 不存在于词向量中
# 鞋字 : 不存在于词向量中
# 用小本 : 不存在于词向量中
# Choice : 不存在于词向量中
# 年装 : 不存在于词向量中
# 我成 : 不存在于词向量中
# 电原 : 不存在于词向量中
# 块儿 : 不存在于词向量中
# 日式 : 不存在于词向量中
# 海事 : 不存在于词向量中
# 迪迪 : 不存在于词向量中
# 香水 : 不存在于词向量中
# 浓香型 : 不存在于词向量中
# 降过 : 不存在于词向量中
# 3.78 : 不存在于词向量中
# Ghz : 不存在于词向量中
# 本生 : 不存在于词向量中
# 薄个 : 不存在于词向量中
# G400 : 不存在于词向量中
# 稳压 : 不存在于词向量中
# 对劲 : 不存在于词向量中
# 机带 : 不存在于词向量中
# 寄走 : 不存在于词向量中
# 男式 : 不存在于词向量中
# 人代送 : 不存在于词向量中
# 有绒 : 不存在于词向量中
# 冻成 : 不存在于词向量中
# 算给力 : 不存在于词向量中
# 发次 : 不存在于词向量中
# 海淘 : 不存在于词向量中
# 停歇 : 不存在于词向量中
# 处易 : 不存在于词向量中
# 人刚 : 不存在于词向量中
# 该处 : 不存在于词向量中
# 公认 : 不存在于词向量中
# 心通 : 不存在于词向量中
# 看鲁 : 不存在于词向量中
# 七万 : 不存在于词向量中
# 船不翻 : 不存在于词向量中
# 港行 : 不存在于词向量中
# 配个音 : 不存在于词向量中
# 935 : 不存在于词向量中
# 牛才 : 不存在于词向量中
# 愿贵店 : 不存在于词向量中
# 以下内容 : 不存在于词向量中
# 制胜 : 不存在于词向量中
# 法宝 : 不存在于词向量中
# Nice : 不存在于词向量中
# 营地 : 不存在于词向量中
# 客体 : 不存在于词向量中
# 太隆音 : 不存在于词向量中
# 有希要 : 不存在于词向量中
# 期到 : 不存在于词向量中
# 几会 : 不存在于词向量中
# 纸箱装 : 不存在于词向量中
# 邱邱 : 不存在于词向量中
# 常带 : 不存在于词向量中
# 缝衣针 : 不存在于词向量中
# 背会 : 不存在于词向量中
# 细评 : 不存在于词向量中
# 能塞纸 : 不存在于词向量中
# 时得 : 不存在于词向量中
# 贝贝 : 不存在于词向量中
# 一零玖玖 : 不存在于词向量中
# 全在响 : 不存在于词向量中
# 松着 : 不存在于词向量中
# 甚高 : 不存在于词向量中
# hearts : 不存在于词向量中
# 连原 : 不存在于词向量中
# 硬外 : 不存在于词向量中
# 浅艾 : 不存在于词向量中
# 所性 : 不存在于词向量中
# 得不偿失 : 不存在于词向量中
# 烫烫 : 不存在于词向量中
# 轰隆隆 : 不存在于词向量中
# 嗲 : 不存在于词向量中
# 比战 : 不存在于词向量中
# 比小新 : 不存在于词向量中
# 6583 : 不存在于词向量中
# 磨得 : 不存在于词向量中
# 快出 : 不存在于词向量中
# 认真学习 : 不存在于词向量中
# 体感接 : 不存在于词向量中
# 机哟 : 不存在于词向量中
# 不冷不热 : 不存在于词向量中
# 前框 : 不存在于词向量中
# 速干 : 不存在于词向量中
# 实发 : 不存在于词向量中
# 货主 : 不存在于词向量中
# 微信收 : 不存在于词向量中
# 字点 : 不存在于词向量中
# 学习者 : 不存在于词向量中
# 买太拉 : 不存在于词向量中
# 播卡到 : 不存在于词向量中
# 360N4s : 不存在于词向量中
# 三只 : 不存在于词向量中
# 卖会 : 不存在于词向量中
# 高后 : 不存在于词向量中
# FAST : 不存在于词向量中
# BOOT : 不存在于词向量中
# 大挺 : 不存在于词向量中
# 爽爆 : 不存在于词向量中
# 买膜购 : 不存在于词向量中
# 包中 : 不存在于词向量中
# 片有 : 不存在于词向量中
# 我拿牙开 : 不存在于词向量中
# 坏人 : 不存在于词向量中
# 买粉 : 不存在于词向量中
# 艾泽拉斯 : 不存在于词向量中
# 大开 : 不存在于词向量中
# 稍火 : 不存在于词向量中
# 中老 : 不存在于词向量中
# 渗液 : 不存在于词向量中
# 电插头 : 不存在于词向量中
# 台湾版 : 不存在于词向量中
# 减振 : 不存在于词向量中
# 哎要 : 不存在于词向量中
# 人白 : 不存在于词向量中
# 积压品 : 不存在于词向量中
# 西捷 : 不存在于词向量中
# 底端 : 不存在于词向量中
# 本冲 : 不存在于词向量中
# 真不杂 : 不存在于词向量中
# 我烂 : 不存在于词向量中
# 中本 : 不存在于词向量中
# KTV : 不存在于词向量中
# 数字机 : 不存在于词向量中
# 质保卡 : 不存在于词向量中
# 599.9 : 不存在于词向量中
# 549 : 不存在于词向量中
# 不红 : 不存在于词向量中
# 不绿 : 不存在于词向量中
# 不白 : 不存在于词向量中
# 信营 : 不存在于词向量中
# 再全 : 不存在于词向量中
# 38921 : 不存在于词向量中
# 冷血 : 不存在于词向量中
# 39097 : 不存在于词向量中
# 受客 : 不存在于词向量中
# 太累心 : 不存在于词向量中
# 巨爽 : 不存在于词向量中
# 网开个 : 不存在于词向量中
# 前购 : 不存在于词向量中
# 二则 : 不存在于词向量中
# 其盖 : 不存在于词向量中
# 女者 : 不存在于词向量中
# 辨认 : 不存在于词向量中
# 选该 : 不存在于词向量中
# 机杂 : 不存在于词向量中
# 全频 : 不存在于词向量中
# 少多 : 不存在于词向量中
# 南昌市 : 不存在于词向量中
# 一堆堆 : 不存在于词向量中
# 一妈批 : 不存在于词向量中
# 税号 : 不存在于词向量中
# 不耐其烦 : 不存在于词向量中
# 泥石流 : 不存在于词向量中
# 自制 : 不存在于词向量中
# 普版 : 不存在于词向量中
# Skr : 不存在于词向量中
# 蚊 : 不存在于词向量中
# miui9.5 : 不存在于词向量中
# 反超 : 不存在于词向量中
# ipx : 不存在于词向量中
# COF : 不存在于词向量中
# 来缓 : 不存在于词向量中
# 总和 : 不存在于词向量中
# 拉积 : 不存在于词向量中
# 服装鞋帽 : 不存在于词向量中
# 幸福感 : 不存在于词向量中
# 互动 : 不存在于词向量中
# 一建锁 : 不存在于词向量中
# 保障法 : 不存在于词向量中
# 158.00 : 不存在于词向量中
# 玩貝 : 不存在于词向量中
# 干干的 : 不存在于词向量中
# 480P : 不存在于词向量中
# 快地 : 不存在于词向量中
# 红斑 : 不存在于词向量中
# 866 : 不存在于词向量中
# 761 : 不存在于词向量中
# 炮罗来 : 不存在于词向量中
# 以好 : 不存在于词向量中
# 多次重复 : 不存在于词向量中
# 进才 : 不存在于词向量中
# 从安卓换 : 不存在于词向量中
# 尝尝鲜 : 不存在于词向量中
# 靴太硬 : 不存在于词向量中
# 1111111111111111111111 : 不存在于词向量中
# 太潮 : 不存在于词向量中
# 从配 : 不存在于词向量中
# 自恋 : 不存在于词向量中
# 119 : 不存在于词向量中
# 宽容 : 不存在于词向量中
# 谢娜 : 不存在于词向量中
# 看戏 : 不存在于词向量中
# 机放 : 不存在于词向量中
# 开裆裤 : 不存在于词向量中
# 哪到 : 不存在于词向量中
# 员真 : 不存在于词向量中
# 编 : 不存在于词向量中
# 再收 : 不存在于词向量中
# 经济效益 : 不存在于词向量中
# 信会卡 : 不存在于词向量中
# 随买 : 不存在于词向量中
# 别乱标 : 不存在于词向量中
# 500W : 不存在于词向量中
# 键锁 : 不存在于词向量中
# 知悉 : 不存在于词向量中
# cn : 不存在于词向量中
# BkdcQk : 不存在于词向量中
# 那丫都 : 不存在于词向量中
# 可玩 : 不存在于词向量中
# 刚录 : 不存在于词向量中
# wids : 不存在于词向量中
# CPU2 : 不存在于词向量中
# 安全可靠 : 不存在于词向量中
# 最省 : 不存在于词向量中
# 之百防 : 不存在于词向量中
# 有圈 : 不存在于词向量中
# 虚电用 : 不存在于词向量中
# 电差 : 不存在于词向量中
# 直往 : 不存在于词向量中
# 100mAh : 不存在于词向量中
# 我破 : 不存在于词向量中
# 经手 : 不存在于词向量中
# 割破 : 不存在于词向量中
# 活宝 : 不存在于词向量中
# 961429 : 不存在于词向量中
# 国营 : 不存在于词向量中
# 嘢 : 不存在于词向量中
# 特供 : 不存在于词向量中
# 线来 : 不存在于词向量中
# 台席加 : 不存在于词向量中
# 敌不过 : 不存在于词向量中
# 看家 : 不存在于词向量中
# 工时费 : 不存在于词向量中
# 快盘 : 不存在于词向量中
# 会烂 : 不存在于词向量中
# 三五 : 不存在于词向量中
# 之难用 : 不存在于词向量中
# 员马浩 : 不存在于词向量中
# 这去 : 不存在于词向量中
# 335010 : 不存在于词向量中
# 302266 : 不存在于词向量中
# 后安兔 : 不存在于词向量中
# 28.2 : 不存在于词向量中
# 两米 : 不存在于词向量中
# 耳轻 : 不存在于词向量中
# 电源网 : 不存在于词向量中
# 6700 : 不存在于词向量中
# 豆腐脑 : 不存在于词向量中
# 中大 : 不存在于词向量中
# 包难 : 不存在于词向量中
# 宽脚 : 不存在于词向量中
# 布面 : 不存在于词向量中
# 京洞 : 不存在于词向量中
# 没道理 : 不存在于词向量中
# 铁将军 : 不存在于词向量中
# 961N : 不存在于词向量中
# 76418059738 : 不存在于词向量中
# 铭悦 : 不存在于词向量中
# 44709 : 不存在于词向量中
# 号店 : 不存在于词向量中
# 前轮 : 不存在于词向量中
# 刮掉 : 不存在于词向量中
# 35CM : 不存在于词向量中
# 垫片 : 不存在于词向量中
# 找大 : 不存在于词向量中
# 口头 : 不存在于词向量中
# 动平衡 : 不存在于词向量中
# 叫嚣 : 不存在于词向量中
# 司法程序 : 不存在于词向量中
# 一超 : 不存在于词向量中
# 武 : 不存在于词向量中
# 飞得 : 不存在于词向量中
# 丑人 : 不存在于词向量中
# 汤话 : 不存在于词向量中
# 拒不承认 : 不存在于词向量中
# 热水器 : 不存在于词向量中
# 六口 : 不存在于词向量中
# 北京市消协 : 不存在于词向量中
# 百世 : 不存在于词向量中
# 徒有 : 不存在于词向量中
# 虚表 : 不存在于词向量中
# 问换 : 不存在于词向量中
# 出不起 : 不存在于词向量中
# 人花 : 不存在于词向量中
# 时老 : 不存在于词向量中
# 如可无星 : 不存在于词向量中
# 当给 : 不存在于词向量中
# 黑盒子 : 不存在于词向量中
# 行驶 : 不存在于词向量中
# 多幅 : 不存在于词向量中
# a21 : 不存在于词向量中
# 登不进 : 不存在于词向量中
# 师先 : 不存在于词向量中
# 货没送 : 不存在于词向量中
# 通关 : 不存在于词向量中
# 断字 : 不存在于词向量中
# 很台 : 不存在于词向量中
# 余个 : 不存在于词向量中
# 取整 : 不存在于词向量中
# 妲 : 不存在于词向量中
# 心呐 : 不存在于词向量中
# 裤筒 : 不存在于词向量中
# 显胖 : 不存在于词向量中
# 毛态 : 不存在于词向量中
# 摊平到 : 不存在于词向量中
# 面掌托 : 不存在于词向量中
# 小老婆 : 不存在于词向量中
# 伍佰多园 : 不存在于词向量中
# 公司总部 : 不存在于词向量中
# 手同 : 不存在于词向量中
# 鼻 : 不存在于词向量中
# 特朗普 : 不存在于词向量中
# 乱猜 : 不存在于词向量中
# 往死卡 : 不存在于词向量中
# 一棵树 : 不存在于词向量中
# 道谦 : 不存在于词向量中
# 电活 : 不存在于词向量中
# 1800ma : 不存在于词向量中
# 1998 : 不存在于词向量中
# 装都装 : 不存在于词向量中
# min : 不存在于词向量中
# 反恐精英 : 不存在于词向量中
# 新任 : 不存在于词向量中
# 牛魔王 : 不存在于词向量中
# 先设 : 不存在于词向量中
# 撤换 : 不存在于词向量中
# 连想 : 不存在于词向量中
# 穿破 : 不存在于词向量中
# 蓝楹 : 不存在于词向量中
# 3APP : 不存在于词向量中
# 分够 : 不存在于词向量中
# 多捞 : 不存在于词向量中
# 水土不服 : 不存在于词向量中
# 心率 : 不存在于词向量中
# 那支 : 不存在于词向量中
# SPEN : 不存在于词向量中
# 玩去 : 不存在于词向量中
# 5555555555 : 不存在于词向量中
# 下阵点 : 不存在于词向量中
# 时误 : 不存在于词向量中
# y7kp : 不存在于词向量中
# 回开 : 不存在于词向量中
# 做坏 : 不存在于词向量中
# 太屎 : 不存在于词向量中
# 比中 : 不存在于词向量中
# ipai : 不存在于词向量中
# 价偏 : 不存在于词向量中
# 他换 : 不存在于词向量中
# 员退 : 不存在于词向量中
# 员带 : 不存在于词向量中
# 闹事 : 不存在于词向量中
# 罚钱 : 不存在于词向量中
# 黑社会 : 不存在于词向量中
# 帮人忙 : 不存在于词向量中
# root2 : 不存在于词向量中
# 安卓像 : 不存在于词向量中
# mkv : 不存在于词向量中
# i5qq : 不存在于词向量中
# 精疲力尽 : 不存在于词向量中
# 斩钉截铁 : 不存在于词向量中
# 入库 : 不存在于词向量中
# 2.24 : 不存在于词向量中
# 服服服 : 不存在于词向量中
# 屏抖 : 不存在于词向量中
# 万拍 : 不存在于词向量中
# 偏得 : 不存在于词向量中
# 玩应儿 : 不存在于词向量中
# 苦力 : 不存在于词向量中
# 难解 : 不存在于词向量中
# my : 不存在于词向量中
# god : 不存在于词向量中
# 不以 : 不存在于词向量中
# 纪念日 : 不存在于词向量中
# 会时常 : 不存在于词向量中
# 打孔 : 不存在于词向量中
# cpu65 : 不存在于词向量中
# 不多花 : 不存在于词向量中
# 别装 : 不存在于词向量中
# 那键 : 不存在于词向量中
# 庋 : 不存在于词向量中
# 没味 : 不存在于词向量中
# 反个 : 不存在于词向量中
# 几兆 : 不存在于词向量中
# 优艾斯 : 不存在于词向量中
# 货不贵 : 不存在于词向量中
# 扑面 : 不存在于词向量中
# 差坑 : 不存在于词向量中
# 但仅线 : 不存在于词向量中
# 太土 : 不存在于词向量中
# 梵净山 : 不存在于词向量中
# 扣押 : 不存在于词向量中
# 争议 : 不存在于词向量中
# blu : 不存在于词向量中
# 高下 : 不存在于词向量中
# FE : 不存在于词向量中
# 一忙 : 不存在于词向量中
# 忘办 : 不存在于词向量中
# 锈 : 不存在于词向量中
# 渍 : 不存在于词向量中
# 三四万块 : 不存在于词向量中
# mak : 不存在于词向量中
# 没人用 : 不存在于词向量中
# 惊细 : 不存在于词向量中
# 出为 : 不存在于词向量中
# 率先 : 不存在于词向量中
# 10GT : 不存在于词向量中
# 第一手 : 不存在于词向量中
# EMUI9.0 : 不存在于词向量中
# 糙人 : 不存在于词向量中
# 拱手 : 不存在于词向量中
# 38833 : 不存在于词向量中
# 礼品券 : 不存在于词向量中
# 没救手 : 不存在于词向量中
# 生吞 : 不存在于词向量中
# 胖瘦 : 不存在于词向量中
# 型码 : 不存在于词向量中
# 我忙 : 不存在于词向量中
# 能大点 : 不存在于词向量中
# 去验机 : 不存在于词向量中
# 带根 : 不存在于词向量中
# 用配 : 不存在于词向量中
# 后触 : 不存在于词向量中
# 大银买 : 不存在于词向量中
# 配牌 : 不存在于词向量中
# 有音 : 不存在于词向量中
# 碎花 : 不存在于词向量中
# 购到 : 不存在于词向量中
# 几百公里 : 不存在于词向量中
# 吐糟 : 不存在于词向量中
# 过场 : 不存在于词向量中
# 先涨 : 不存在于词向量中
# 1439 : 不存在于词向量中
# 药品 : 不存在于词向量中
# 楚留香 : 不存在于词向量中
# 孤寒 : 不存在于词向量中
# 不建意 : 不存在于词向量中
# 项羽 : 不存在于词向量中
# 绿化 : 不存在于词向量中
# 太艳 : 不存在于词向量中
# 学期 : 不存在于词向量中
# 时代感 : 不存在于词向量中
# 问微信 : 不存在于词向量中
# 提亮 : 不存在于词向量中
# 搬书 : 不存在于词向量中
# 搬个 : 不存在于词向量中
# 闹不清 : 不存在于词向量中
# 太水太渣 : 不存在于词向量中
# 触不动 : 不存在于词向量中
# 排面 : 不存在于词向量中
# 以此为由 : 不存在于词向量中
# 称道 : 不存在于词向量中
# 1803 : 不存在于词向量中
# 风速 : 不存在于词向量中
# 吱吱响声 : 不存在于词向量中
# aoc : 不存在于词向量中
# 市县 : 不存在于词向量中
# 寄厂 : 不存在于词向量中
# 正用 : 不存在于词向量中
# 高危 : 不存在于词向量中
# 这就样 : 不存在于词向量中
# 买笔 : 不存在于词向量中
# 神经衰弱 : 不存在于词向量中
# 怕冷 : 不存在于词向量中
# 热帖 : 不存在于词向量中
# 看不大出 : 不存在于词向量中
# 天会 : 不存在于词向量中
# 空放 : 不存在于词向量中
# 满嘴胡话 : 不存在于词向量中
# lowB : 不存在于词向量中
# 头晚 : 不存在于词向量中
# 液涂 : 不存在于词向量中
# 消的 : 不存在于词向量中
# 透进 : 不存在于词向量中
# 水碰 : 不存在于词向量中
# 出资 : 不存在于词向量中
# Vgame : 不存在于词向量中
# 革命烈士 : 不存在于词向量中
# BRT : 不存在于词向量中
# 不新 : 不存在于词向量中
# 又款 : 不存在于词向量中
# 修是 : 不存在于词向量中
# 借给 : 不存在于词向量中
# 有卷 : 不存在于词向量中
# 110000 : 不存在于词向量中
# 破麦 : 不存在于词向量中
# 成功网 : 不存在于词向量中
# WI : 不存在于词向量中
# FI : 不存在于词向量中
# 来配 : 不存在于词向量中
# 包保 : 不存在于词向量中
# 防毒 : 不存在于词向量中
# 新洗 : 不存在于词向量中
# 臭不可闻 : 不存在于词向量中
# 发货单 : 不存在于词向量中
# 这弄 : 不存在于词向量中
# 变少 : 不存在于词向量中
# C7 : 不存在于词向量中
# MIX6 : 不存在于词向量中
# 夺宝 : 不存在于词向量中
# 岛上 : 不存在于词向量中
# 碴 : 不存在于词向量中
# 下垂 : 不存在于词向量中
# 点用 : 不存在于词向量中
# 休想 : 不存在于词向量中
# 可拍照 : 不存在于词向量中
# 度睿频 : 不存在于词向量中
# 起后 : 不存在于词向量中
# 不慌 : 不存在于词向量中
# 赚够 : 不存在于词向量中
# 5.30 : 不存在于词向量中
# 日价保 : 不存在于词向量中
# 日过 : 不存在于词向量中
# 还抗 : 不存在于词向量中
# 酌情 : 不存在于词向量中
# I78750H : 不存在于词向量中
# gtx1050Ti4G : 不存在于词向量中
# 悬殊 : 不存在于词向量中
# 人长 : 不存在于词向量中
# 本科学历 : 不存在于词向量中
# 沙亚 : 不存在于词向量中
# 丨 : 不存在于词向量中
# 优其前 : 不存在于词向量中
# 清差 : 不存在于词向量中
# 班刚 : 不存在于词向量中
# 漏进 : 不存在于词向量中
# 慢劲 : 不存在于词向量中
# 不做声 : 不存在于词向量中
# 我店 : 不存在于词向量中
# 屏真 : 不存在于词向量中
# 冰川 : 不存在于词向量中
# 最腊 : 不存在于词向量中
# 追塑 : 不存在于词向量中
# 批用 : 不存在于词向量中
# 枇用 : 不存在于词向量中
# 知根知底 : 不存在于词向量中
# 俩家 : 不存在于词向量中
# 大失 : 不存在于词向量中
# 天算 : 不存在于词向量中
# 带光 : 不存在于词向量中
# 按件 : 不存在于词向量中
# 手正 : 不存在于词向量中
# 双全 : 不存在于词向量中
# 还领 : 不存在于词向量中
# 时下个 : 不存在于词向量中
# 924 : 不存在于词向量中
# 花会 : 不存在于词向量中
# 22.2 : 不存在于词向量中
# 6.6% : 不存在于词向量中
# 小意思 : 不存在于词向量中
# 醒屏 : 不存在于词向量中
# 不字 : 不存在于词向量中
# 挽救 : 不存在于词向量中
# 无名 : 不存在于词向量中
# 更美 : 不存在于词向量中
# 收贷 : 不存在于词向量中
# 脆得根 : 不存在于词向量中
# 蛋壳 : 不存在于词向量中
# 头和线 : 不存在于词向量中
# 带来带去 : 不存在于词向量中
# 赞吐槽 : 不存在于词向量中
# 空开 : 不存在于词向量中
# 4000MAH : 不存在于词向量中
# X1carbon : 不存在于词向量中
# xbox : 不存在于词向量中
# mojang : 不存在于词向量中
# 比开 : 不存在于词向量中
# 托太多 : 不存在于词向量中
# 奏效 : 不存在于词向量中
# 6.16 : 不存在于词向量中
# 没货学 : 不存在于词向量中
# 人收 : 不存在于词向量中
# 无二 : 不存在于词向量中
# 评会 : 不存在于词向量中
# 滋响 : 不存在于词向量中
# 自送 : 不存在于词向量中
# 长袜 : 不存在于词向量中
# 心血 : 不存在于词向量中
# 压爆 : 不存在于词向量中
# 欺主 : 不存在于词向量中
# 古人云 : 不存在于词向量中
# 兴极 : 不存在于词向量中
# 64G2399 : 不存在于词向量中
# 128G2399 : 不存在于词向量中
# 称得上 : 不存在于词向量中
# 五星级 : 不存在于词向量中
# 以退 : 不存在于词向量中
# 沂源 : 不存在于词向量中
# 公布出来 : 不存在于词向量中
# 睡大觉 : 不存在于词向量中
# 货邮 : 不存在于词向量中
# 货真 : 不存在于词向量中
# 地高 : 不存在于词向量中
# 2.21 : 不存在于词向量中
# 妇联 : 不存在于词向量中
# 好物 : 不存在于词向量中
# 二封 : 不存在于词向量中
# 浮现 : 不存在于词向量中
# 篮色区 : 不存在于词向量中
# 人挤 : 不存在于词向量中
# 线针 : 不存在于词向量中
# 起点 : 不存在于词向量中
# 三节 : 不存在于词向量中
# 7799 : 不存在于词向量中
# 做失 : 不存在于词向量中
# 乱叫 : 不存在于词向量中
# 四千元 : 不存在于词向量中
# 2006 : 不存在于词向量中
# 泡面 : 不存在于词向量中
# 电刚 : 不存在于词向量中
# 齿轮 : 不存在于词向量中
# 我刷个 : 不存在于词向量中
# 中山装 : 不存在于词向量中
# 人晒单 : 不存在于词向量中
# 有半屏 : 不存在于词向量中
# 很輕薄 : 不存在于词向量中
# 機身 : 不存在于词向量中
# 較長 : 不存在于词向量中
# 機背 : 不存在于词向量中
# 機 : 不存在于词向量中
# 近似 : 不存在于词向量中
# 性價 : 不存在于词向量中
# IO : 不存在于词向量中
# 英文歌曲 : 不存在于词向量中
# 羊头 : 不存在于词向量中
# 卖狗肉 : 不存在于词向量中
# 懊糟 : 不存在于词向量中
# 真不撑 : 不存在于词向量中
# 缠上 : 不存在于词向量中
# 移除 : 不存在于词向量中
# 发完货 : 不存在于词向量中
# 分拨 : 不存在于词向量中
# 没人会管 : 不存在于词向量中
# 滞洪区 : 不存在于词向量中
# 搞上去 : 不存在于词向量中
# 害惨 : 不存在于词向量中
# mui9 : 不存在于词向量中
# 先录 : 不存在于词向量中
# 腿脚 : 不存在于词向量中
# 骑着 : 不存在于词向量中
# 礼服 : 不存在于词向量中
# 真特步 : 不存在于词向量中
# 7.9 : 不存在于词向量中
# 可船 : 不存在于词向量中
# 选三送 : 不存在于词向量中
# 选时 : 不存在于词向量中
# 选重 : 不存在于词向量中
# 货号 : 不存在于词向量中
# 扣京否 : 不存在于词向量中
# 笨人 : 不存在于词向量中
# 美用 : 不存在于词向量中
# 选则 : 不存在于词向量中
# 假双卡 : 不存在于词向量中
# 说安交 : 不存在于词向量中
# 纸卡 : 不存在于词向量中
# 扯开 : 不存在于词向量中
# 难保 : 不存在于词向量中
# 率低 : 不存在于词向量中
# 不缩 : 不存在于词向量中
# z17minis : 不存在于词向量中
# 米红米 : 不存在于词向量中
# 五餐 : 不存在于词向量中
# 嫌大用 : 不存在于词向量中
# 搞清 : 不存在于词向量中
# 数十次 : 不存在于词向量中
# 影响力 : 不存在于词向量中
# 期就付 : 不存在于词向量中
# 上乱 : 不存在于词向量中
# 耗到 : 不存在于词向量中
# 2414h : 不存在于词向量中
# 偏局 : 不存在于词向量中
# 好断 : 不存在于词向量中
# 还变 : 不存在于词向量中
# 暗圈 : 不存在于词向量中
# 奉陪到底 : 不存在于词向量中
# ___ : 不存在于词向量中
# 充起 : 不存在于词向量中
# 45678 : 不存在于词向量中
# 惹事 : 不存在于词向量中
# 会败 : 不存在于词向量中
# 很惨 : 不存在于词向量中
# 愿像 : 不存在于词向量中
# 主播 : 不存在于词向量中
# IPhone : 不存在于词向量中
# 年全 : 不存在于词向量中
# 太翠 : 不存在于词向量中
# 说拉几 : 不存在于词向量中
# 本宫 : 不存在于词向量中
# 网络故障 : 不存在于词向量中
# 厂机 : 不存在于词向量中
# 祝老罗 : 不存在于词向量中
# 有多远 : 不存在于词向量中
# 倾销 : 不存在于词向量中
# 油腻腻 : 不存在于词向量中
# RE : 不存在于词向量中
# 机当 : 不存在于词向量中
# 0616 : 不存在于词向量中
# 0619 : 不存在于词向量中
# PPT2 : 不存在于词向量中
# 会赠 : 不存在于词向量中
# 图隔 : 不存在于词向量中
# 留余地 : 不存在于词向量中
# BaiLei : 不存在于词向量中
# 人渣 : 不存在于词向量中
# 没此 : 不存在于词向量中
# 驱 : 不存在于词向量中
# 坏须 : 不存在于词向量中
# 会疙手 : 不存在于词向量中
# 无商不奸 : 不存在于词向量中
# 万里 : 不存在于词向量中
# 苏爱 : 不存在于词向量中
# 多鞋 : 不存在于词向量中
# 4S : 不存在于词向量中
# 校正 : 不存在于词向量中
# 初上 : 不存在于词向量中
# 初试 : 不存在于词向量中
# 搓洗 : 不存在于词向量中
# 染到 : 不存在于词向量中
# 合不拢嘴 : 不存在于词向量中
# 1269 : 不存在于词向量中
# 宝放高 : 不存在于词向量中
# 小婉 : 不存在于词向量中
# 但调 : 不存在于词向量中
# 明不虚传 : 不存在于词向量中
# 万事俱备 : 不存在于词向量中
# M3MAX : 不存在于词向量中
# 11.18 : 不存在于词向量中
# 阴毛 : 不存在于词向量中
# 脚短 : 不存在于词向量中
# 四中 : 不存在于词向量中
# 人蛮 : 不存在于词向量中
# 11.02 : 不存在于词向量中
# ture : 不存在于词向量中
# 5W : 不存在于词向量中
# 展望 : 不存在于词向量中
# 更帅 : 不存在于词向量中
# 点到点 : 不存在于词向量中
# 文子 : 不存在于词向量中
# 多想 : 不存在于词向量中
# 3dtouch : 不存在于词向量中
# 慢慢吞吞 : 不存在于词向量中
# sony : 不存在于词向量中
# 击棒 : 不存在于词向量中
# 列表 : 不存在于词向量中
# UIY : 不存在于词向量中
# 侧透版 : 不存在于词向量中
# 想太好 : 不存在于词向量中
# TMB : 不存在于词向量中
# 强过 : 不存在于词向量中
# 卡特 : 不存在于词向量中
# 三千六百 : 不存在于词向量中
# 扔下 : 不存在于词向量中
# 很柔蛮 : 不存在于词向量中
# 独到 : 不存在于词向量中
# 总跑 : 不存在于词向量中
# 偏厚 : 不存在于词向量中
# 记忆力 : 不存在于词向量中
# 用笔 : 不存在于词向量中
# 重命名 : 不存在于词向量中
# 缩减成 : 不存在于词向量中
# 第四点 : 不存在于词向量中
# 倾倒 : 不存在于词向量中
# 肉肉 : 不存在于词向量中
# 较厚 : 不存在于词向量中
# 劝哈 : 不存在于词向量中
# 慎行 : 不存在于词向量中
# wcnnngb : 不存在于词向量中
# 调大有 : 不存在于词向量中
# 认坑 : 不存在于词向量中
# 扫单 : 不存在于词向量中
# 放映 : 不存在于词向量中
# 同屏 : 不存在于词向量中
# 信发 : 不存在于词向量中
# 再返 : 不存在于词向量中
# 塑料玩具 : 不存在于词向量中
# 时录 : 不存在于词向量中
# 干看 : 不存在于词向量中
# 来路 : 不存在于词向量中
# 家比 : 不存在于词向量中
# 苦果 : 不存在于词向量中
# lenss : 不存在于词向量中
# lou : 不存在于词向量中
# 有下 : 不存在于词向量中
# 万要 : 不存在于词向量中
# 美眉 : 不存在于词向量中
# 傻大 : 不存在于词向量中
# 二黑东 : 不存在于词向量中
# 小脚趾头 : 不存在于词向量中
# 问双 : 不存在于词向量中
# 111GB : 不存在于词向量中
# 秀和机 : 不存在于词向量中
# 老响 : 不存在于词向量中
# 图档 : 不存在于词向量中
# 清秀 : 不存在于词向量中
# 歌卡歌 : 不存在于词向量中
# 眼花缭乱 : 不存在于词向量中
# 不吊造 : 不存在于词向量中
# 记事 : 不存在于词向量中
# 乖要 : 不存在于词向量中
# 三十厘米 : 不存在于词向量中
# 抢来 : 不存在于词向量中
# 花圈 : 不存在于词向量中
# 死全 : 不存在于词向量中
# 单才 : 不存在于词向量中
# 机作 : 不存在于词向量中
# 特高 : 不存在于词向量中
# 国产化 : 不存在于词向量中
# LPDDR4 : 不存在于词向量中
# 精明 : 不存在于词向量中
# 一两月 : 不存在于词向量中
# 有延 : 不存在于词向量中
# 移动镜头 : 不存在于词向量中
# 不敢想像 : 不存在于词向量中
# Iphone8 : 不存在于词向量中
# 落位 : 不存在于词向量中
# 1789 : 不存在于词向量中
# 消磁 : 不存在于词向量中
# 丰润 : 不存在于词向量中
# 半给 : 不存在于词向量中
# 恋旧 : 不存在于词向量中
# 员太度 : 不存在于词向量中
# 便秘 : 不存在于词向量中
# FX80 : 不存在于词向量中
# 52% : 不存在于词向量中
# 零六个 : 不存在于词向量中
# 开键 : 不存在于词向量中
# 灯时 : 不存在于词向量中
# 无几 : 不存在于词向量中
# 提意见 : 不存在于词向量中
# 18g : 不存在于词向量中
# 好桑心 : 不存在于词向量中
# 轻得 : 不存在于词向量中
# 照张 : 不存在于词向量中
# 好味 : 不存在于词向量中
# 弄伤 : 不存在于词向量中
# 背身 : 不存在于词向量中
# 出到 : 不存在于词向量中
# 软屏 : 不存在于词向量中
# 我套 : 不存在于词向量中
# 深民 : 不存在于词向量中
# 话机 : 不存在于词向量中
# 成事 : 不存在于词向量中
# 介面 : 不存在于词向量中
# 顺让 : 不存在于词向量中
# 短则 : 不存在于词向量中
# 晴空万里 : 不存在于词向量中
# 路运 : 不存在于词向量中
# 只字片语 : 不存在于词向量中
# 那货 : 不存在于词向量中
# 卖鞋 : 不存在于词向量中
# swift2 : 不存在于词向量中
# 重些 : 不存在于词向量中
# 渣机 : 不存在于词向量中
# miu10 : 不存在于词向量中
# 啧走 : 不存在于词向量中
# 组撒 : 不存在于词向量中
# 能为 : 不存在于词向量中
# 千分之一 : 不存在于词向量中
# 严厉批评 : 不存在于词向量中
# 强于 : 不存在于词向量中
# 开快 : 不存在于词向量中
# 屏刷 : 不存在于词向量中
# 帮买验 : 不存在于词向量中
# 钱配 : 不存在于词向量中
# 发抖 : 不存在于词向量中
# 二款 : 不存在于词向量中
# 很方 : 不存在于词向量中
# 需然 : 不存在于词向量中
# 一暖 : 不存在于词向量中
# 瓶子 : 不存在于词向量中
# 碰倒 : 不存在于词向量中
# pao : 不存在于词向量中
# 鞋挺轻 : 不存在于词向量中
# 建湿手 : 不存在于词向量中
# 下卡顿 : 不存在于词向量中
# 摩托车 : 不存在于词向量中
# 人体工学 : 不存在于词向量中
# NIKE : 不存在于词向量中
# 冻人 : 不存在于词向量中
# 片场 : 不存在于词向量中
# 焊点 : 不存在于词向量中
# l5640 : 不存在于词向量中
# 购前 : 不存在于词向量中
# 下比 : 不存在于词向量中
# 不合情理 : 不存在于词向量中
# tm3 : 不存在于词向量中
# 天目 : 不存在于词向量中
# 西路 : 不存在于词向量中
# 钥题 : 不存在于词向量中
# 罢罢罢 : 不存在于词向量中
# 302123 : 不存在于词向量中
# 口才 : 不存在于词向量中
# 屈才 : 不存在于词向量中
# 观注 : 不存在于词向量中
# 扣不拢 : 不存在于词向量中
# 管理软件 : 不存在于词向量中
# 嘉 : 不存在于词向量中
# 多举个 : 不存在于词向量中
# 甩头 : 不存在于词向量中
# 已入 : 不存在于词向量中
# 耐不耐滑 : 不存在于词向量中
# 晕过去 : 不存在于词向量中
# 差超差 : 不存在于词向量中
# 脚头 : 不存在于词向量中
# 杨 : 不存在于词向量中
# 愉 : 不存在于词向量中
# 序号 : 不存在于词向量中
# 键点 : 不存在于词向量中
# 上根 : 不存在于词向量中
# 这身 : 不存在于词向量中
# 碗 : 不存在于词向量中
# 冲满格 : 不存在于词向量中
# 驾考 : 不存在于词向量中
# 宝典 : 不存在于词向量中
# 我三防 : 不存在于词向量中
# 二百九十九 : 不存在于词向量中
# 单量 : 不存在于词向量中
# 莫法用 : 不存在于词向量中
# 超滑 : 不存在于词向量中
# 好杂 : 不存在于词向量中
# 旅游鞋 : 不存在于词向量中
# 部份 : 不存在于词向量中
# 路纹 : 不存在于词向量中
# 粗手粗脚 : 不存在于词向量中
# 检 : 不存在于词向量中
# 直得点 : 不存在于词向量中
# 很心水 : 不存在于词向量中
# 小鹏 : 不存在于词向量中
# 精通 : 不存在于词向量中
# 轻按 : 不存在于词向量中
# 小人国 : 不存在于词向量中
# 还大费 : 不存在于词向量中
# 没拿住 : 不存在于词向量中
# 无漏 : 不存在于词向量中
# 烦请 : 不存在于词向量中
# 起巴适 : 不存在于词向量中
# 京金好 : 不存在于词向量中
# 86.1 : 不存在于词向量中
# 小白分 : 不存在于词向量中
# 作作 : 不存在于词向量中
# 憨笑 : 不存在于词向量中
# iTunes : 不存在于词向量中
# 不挂 : 不存在于词向量中
# 202 : 不存在于词向量中
# 永恒 : 不存在于词向量中
# 眼子 : 不存在于词向量中
# 氨纶 : 不存在于词向量中
# 人帅 : 不存在于词向量中
# 美鞋 : 不存在于词向量中
# 以掉 : 不存在于词向量中
# 漆为 : 不存在于词向量中
# 12.14 : 不存在于词向量中
# 拍卖 : 不存在于词向量中
# 大理石 : 不存在于词向量中
# 没提 : 不存在于词向量中
# 坏机 : 不存在于词向量中
# 通报 : 不存在于词向量中
# 散尽 : 不存在于词向量中
# 双九做 : 不存在于词向量中
# 珍珠白 : 不存在于词向量中
# 灰有 : 不存在于词向量中
# 急下 : 不存在于词向量中
# 负面新闻 : 不存在于词向量中
# 唯唯诺诺 : 不存在于词向量中
# 商量余地 : 不存在于词向量中
# 這個 : 不存在于词向量中
# 產品 : 不存在于词向量中
# 下成 : 不存在于词向量中
# 贴屏 : 不存在于词向量中
# 50cm : 不存在于词向量中
# 一冲电 : 不存在于词向量中
# 谈判 : 不存在于词向量中
# 便利店 : 不存在于词向量中
# 小妞 : 不存在于词向量中
# 真不抗 : 不存在于词向量中
# 修太 : 不存在于词向量中
# 布拉 : 不存在于词向量中
# iPhone6plus : 不存在于词向量中
# %% : 不存在于词向量中
# 麻批 : 不存在于词向量中
# 留一证 : 不存在于词向量中
# 嘴角 : 不存在于词向量中
# 酷毙了 : 不存在于词向量中
# 高差 : 不存在于词向量中
# 你会花 : 不存在于词向量中
# 整部 : 不存在于词向量中
# 比换 : 不存在于词向量中
# 喜剧 : 不存在于词向量中
# 用先 : 不存在于词向量中
# 气要 : 不存在于词向量中
# lol2 : 不存在于词向量中
# 朝气 : 不存在于词向量中
# 颜料 : 不存在于词向量中
# ios10.2 : 不存在于词向量中
# 翻叶键 : 不存在于词向量中
# n2s : 不存在于词向量中
# 发国通 : 不存在于词向量中
# 摔出 : 不存在于词向量中
# 国通 : 不存在于词向量中
# 磨划 : 不存在于词向量中
# 实际操作 : 不存在于词向量中
# 蓝频 : 不存在于词向量中
# 商讨 : 不存在于词向量中
# 迟大 : 不存在于词向量中
# 纸币 : 不存在于词向量中
# 大和卡 : 不存在于词向量中
# 17704 : 不存在于词向量中
# 操场 : 不存在于词向量中
# 步进 : 不存在于词向量中
# 特不 : 不存在于词向量中
# 坑太深 : 不存在于词向量中
# 求换 : 不存在于词向量中
# 邵帮 : 不存在于词向量中
# 塞个 : 不存在于词向量中
# 放卡槽 : 不存在于词向量中
# 我连卡 : 不存在于词向量中
# 深资 : 不存在于词向量中
# 几百回 : 不存在于词向量中
# 坑换个 : 不存在于词向量中
# 深爱 : 不存在于词向量中
# 很多很多年 : 不存在于词向量中
# tcl : 不存在于词向量中
# 讲述 : 不存在于词向量中
# pIus : 不存在于词向量中
# noTe5 : 不存在于词向量中
# 想负 : 不存在于词向量中
# 低估 : 不存在于词向量中
# 我瞎点 : 不存在于词向量中
# luhuo : 不存在于词向量中
# 烟盒 : 不存在于词向量中
# 粘水怕 : 不存在于词向量中
# 没比 : 不存在于词向量中
# 人一多 : 不存在于词向量中
# 缓个 : 不存在于词向量中
# 截然不同 : 不存在于词向量中
# 某云好 : 不存在于词向量中
# 诚若 : 不存在于词向量中
# 股胶味 : 不存在于词向量中
# 丧心病狂 : 不存在于词向量中
# 小尾巴 : 不存在于词向量中
# 积点 : 不存在于词向量中
# 终会漏 : 不存在于词向量中
# 划船 : 不存在于词向量中
# 桨 : 不存在于词向量中
# 全靠浪 : 不存在于词向量中
# 双鸿星 : 不存在于词向量中
# 绿萝 : 不存在于词向量中
# 意响 : 不存在于词向量中
# 浮动价格 : 不存在于词向量中
# 三年期 : 不存在于词向量中
# ABC : 不存在于词向量中
# hang : 不存在于词向量中
# shui : 不存在于词向量中
# 放热 : 不存在于词向量中
# 七八家 : 不存在于词向量中
# 净水机 : 不存在于词向量中
# 带卡双 : 不存在于词向量中
# 签字笔 : 不存在于词向量中
# 全铝 : 不存在于词向量中
# J1900 : 不存在于词向量中
# 举着 : 不存在于词向量中
# 公务 : 不存在于词向量中
# caonm : 不存在于词向量中
# 口坏 : 不存在于词向量中
# 堵起来 : 不存在于词向量中
# 口卡 : 不存在于词向量中
# 抗磨 : 不存在于词向量中
# 县上 : 不存在于词向量中
# tpu : 不存在于词向量中
# 差且 : 不存在于词向量中
# 158m : 不存在于词向量中
# 没卡槽 : 不存在于词向量中
# 傻叉 : 不存在于词向量中
# LENOVO : 不存在于词向量中
# 折旧率 : 不存在于词向量中
# 另求 : 不存在于词向量中
# 上书 : 不存在于词向量中
# 异灵 : 不存在于词向量中
# 翻脸不认 : 不存在于词向量中
# caonim : 不存在于词向量中
# 高用 : 不存在于词向量中
# 升降式 : 不存在于词向量中
# 鸟妈 : 不存在于词向量中
# 小二乱 : 不存在于词向量中
# APU : 不存在于词向量中
# rsaquo : 不存在于词向量中
# lsaquo : 不存在于词向量中
# 上移 : 不存在于词向量中
# 敲下来 : 不存在于词向量中
# 板载 : 不存在于词向量中
# 不落色 : 不存在于词向量中
# 赖何 : 不存在于词向量中
# 三级跳 : 不存在于词向量中
# 增城 : 不存在于词向量中
# 180615 : 不存在于词向量中
# 沒压 : 不存在于词向量中
# 用厚 : 不存在于词向量中
# 纽 : 不存在于词向量中
# 骑行 : 不存在于词向量中
# 下体 : 不存在于词向量中
# y430 : 不存在于词向量中
# 销售点 : 不存在于词向量中
# 愈合 : 不存在于词向量中
# 再吐槽 : 不存在于词向量中
# 言行 : 不存在于词向量中
# 纸壳加 : 不存在于词向量中
# 老鼠 : 不存在于词向量中
# 忘关 : 不存在于词向量中
# 不太存 : 不存在于词向量中
# 换平 : 不存在于词向量中
# 起雾 : 不存在于词向量中
# 系统误差 : 不存在于词向量中
# Autocad : 不存在于词向量中
# 小盆友 : 不存在于词向量中
# 小璐璐 : 不存在于词向量中
# 零售 : 不存在于词向量中
# 发二 : 不存在于词向量中
# 盘中 : 不存在于词向量中
# 值有 : 不存在于词向量中
# 橱里 : 不存在于词向量中
# 吊射 : 不存在于词向量中
# 四五点 : 不存在于词向量中
# 那就是说 : 不存在于词向量中
# 30W : 不存在于词向量中
# 会飞 : 不存在于词向量中
# 灯是 : 不存在于词向量中
# 口头语 : 不存在于词向量中
# 吭声 : 不存在于词向量中
# 模裂 : 不存在于词向量中
# 满肚子火 : 不存在于词向量中
# 某加 : 不存在于词向量中
# 开就行 : 不存在于词向量中
# 几里 : 不存在于词向量中
# 三保 : 不存在于词向量中
# 圆珠笔 : 不存在于词向量中
# 机会成本 : 不存在于词向量中
# 上涨幅度 : 不存在于词向量中
# 没权 : 不存在于词向量中
# 没脱 : 不存在于词向量中
# 这门 : 不存在于词向量中
# 综艺节目 : 不存在于词向量中
# 动态图 : 不存在于词向量中
# 脚形 : 不存在于词向量中
# 狠正 : 不存在于词向量中
# 总结性 : 不存在于词向量中
# 92.5 : 不存在于词向量中
# 上扣 : 不存在于词向量中
# 点分 : 不存在于词向量中
# 未半而 : 不存在于词向量中
# 中道 : 不存在于词向量中
# 殂 : 不存在于词向量中
# 瞅准 : 不存在于词向量中
# 破解器 : 不存在于词向量中
# Ri : 不存在于词向量中
# 顺应潮流 : 不存在于词向量中
# 二三十个 : 不存在于词向量中
# 漆是 : 不存在于词向量中
# 多向 : 不存在于词向量中
# 一段距离 : 不存在于词向量中
# 丢三落四 : 不存在于词向量中
# 忘装 : 不存在于词向量中
# 瓷掉 : 不存在于词向量中
# GTX1050Ti : 不存在于词向量中
# 节降 : 不存在于词向量中
# 手抖音 : 不存在于词向量中
# 门上 : 不存在于词向量中
# 心用 : 不存在于词向量中
# 潘多拉 : 不存在于词向量中
# 左后 : 不存在于词向量中
# 连安兔 : 不存在于词向量中
# 配狗 : 不存在于词向量中
# 打印发票 : 不存在于词向量中
# 妈卖 : 不存在于词向量中
# 当说 : 不存在于词向量中
# 千要 : 不存在于词向量中
# 主贝 : 不存在于词向量中
# 前放 : 不存在于词向量中
# 撞车 : 不存在于词向量中
# 认不出来 : 不存在于词向量中
# 我正 : 不存在于词向量中
# 唠嗑 : 不存在于词向量中
# 还踏马 : 不存在于词向量中
# 丢个 : 不存在于词向量中
# 海外版 : 不存在于词向量中
# 机巨烫 : 不存在于词向量中
# 能升 : 不存在于词向量中
# 计算机行业 : 不存在于词向量中
# 比一星 : 不存在于词向量中
# 连输 : 不存在于词向量中
# 上一年 : 不存在于词向量中
# 视频聊 : 不存在于词向量中
# 1300w : 不存在于词向量中
# 500w : 不存在于词向量中
# 店大不缺 : 不存在于词向量中
# 漆黑一片 : 不存在于词向量中
# 学红米 : 不存在于词向量中
# 佐 : 不存在于词向量中
# 台费 : 不存在于词向量中
# 上墙 : 不存在于词向量中
# 只读 : 不存在于词向量中
# 横蛮 : 不存在于词向量中
# 澎湃 : 不存在于词向量中
# 在此期间 : 不存在于词向量中
# 聋子 : 不存在于词向量中
# vissa : 不存在于词向量中
# 买回 : 不存在于词向量中
# 空空荡荡 : 不存在于词向量中
# 四分之三 : 不存在于词向量中
# 锃亮 : 不存在于词向量中
# 66666666 : 不存在于词向量中
# 这爹 : 不存在于词向量中
# 我应 : 不存在于词向量中
# 灰常快 : 不存在于词向量中
# 腰太窄 : 不存在于词向量中
# 22.40 : 不存在于词向量中
# 12.30 : 不存在于词向量中
# 哪有什么 : 不存在于词向量中
# 巨后 : 不存在于词向量中
# 不劳 : 不存在于词向量中
# 揭下 : 不存在于词向量中
# 倒霉事 : 不存在于词向量中
# 捐 : 不存在于词向量中
# 刚差 : 不存在于词向量中
# 软见 : 不存在于词向量中
# EMMc4.5 : 不存在于词向量中
# 掺和 : 不存在于词向量中
# 嚒 : 不存在于词向量中
# 诺曼底 : 不存在于词向量中
# 看真 : 不存在于词向量中
# 佛祖 : 不存在于词向量中
# 卡佛 : 不存在于词向量中
# 上发 : 不存在于词向量中
# 两万五 : 不存在于词向量中
# 推前 : 不存在于词向量中
# 漫画 : 不存在于词向量中
# 跳舞 : 不存在于词向量中
# 亮度高 : 不存在于词向量中
# 绝交 : 不存在于词向量中
# 有花 : 不存在于词向量中
# 枣红色 : 不存在于词向量中
# 不隔用 : 不存在于词向量中
# 屋檐下 : 不存在于词向量中
# 贵能 : 不存在于词向量中
# 闪烁不定 : 不存在于词向量中
# 关察 : 不存在于词向量中
# 畅玩七 : 不存在于词向量中
# 14.4 : 不存在于词向量中
# 雪 : 不存在于词向量中
# 脚磨伤 : 不存在于词向量中
# 上诉 : 不存在于词向量中
# 恶狠狠 : 不存在于词向量中
# 泼 : 不存在于词向量中
# 冷水 : 不存在于词向量中
# 宣泄 : 不存在于词向量中
# 样着 : 不存在于词向量中
# 这码 : 不存在于词向量中
# 490 : 不存在于词向量中
# 有多选 : 不存在于词向量中
# 多选 : 不存在于词向量中
# 笔发 : 不存在于词向量中
# 嘈 : 不存在于词向量中
# 钓客 : 不存在于词向量中
# 你拉及 : 不存在于词向量中
# 刚拨个 : 不存在于词向量中
# 装卡试 : 不存在于词向量中
# 闲多 : 不存在于词向量中
# 12346612379 : 不存在于词向量中
# 从后 : 不存在于词向量中
# 此人 : 不存在于词向量中
# 误删 : 不存在于词向量中
# 车速 : 不存在于词向量中
# 开至 : 不存在于词向量中
# 沃尔沃 : 不存在于词向量中
# 车窗 : 不存在于词向量中
# 极轻 : 不存在于词向量中
# 摸清 : 不存在于词向量中
# 原盒 : 不存在于词向量中
# 周六日 : 不存在于词向量中
# 追要 : 不存在于词向量中
# 防不 : 不存在于词向量中
# 确当 : 不存在于词向量中
# 舅出 : 不存在于词向量中
# 有补 : 不存在于词向量中
# 寸太大 : 不存在于词向量中
# 歧义 : 不存在于词向量中
# 怕人 : 不存在于词向量中
# 烫度 : 不存在于词向量中
# 正常值 : 不存在于词向量中
# 代下 : 不存在于词向量中
# 日程 : 不存在于词向量中
# 7500u : 不存在于词向量中
# 好装个 : 不存在于词向量中
# 硬盘空间 : 不存在于词向量中
# Photoshop : 不存在于词向量中
# 真嘿 : 不存在于词向量中
# 不首 : 不存在于词向量中
# 孔位 : 不存在于词向量中
# 事出 : 不存在于词向量中
# 漏话 : 不存在于词向量中
# 信使 : 不存在于词向量中
# 狗生 : 不存在于词向量中
# 悲凉 : 不存在于词向量中
# 34M : 不存在于词向量中
# 掌阅 : 不存在于词向量中
# 声吵 : 不存在于词向量中
# 射 : 不存在于词向量中
# 三星期 : 不存在于词向量中
# 打不起 : 不存在于词向量中
# 调错 : 不存在于词向量中
# 烦事 : 不存在于词向量中
# 全放 : 不存在于词向量中
# 维护费 : 不存在于词向量中
# 很木 : 不存在于词向量中
# 鬼火 : 不存在于词向量中
# 现己 : 不存在于词向量中
# 刷过 : 不存在于词向量中
# 特丑 : 不存在于词向量中
# 破过音 : 不存在于词向量中
# 磁头 : 不存在于词向量中
# 闪缝 : 不存在于词向量中
# 备忘 : 不存在于词向量中
# 4160 : 不存在于词向量中
# 3120 : 不存在于词向量中
# 這拉 : 不存在于词向量中
# 鍊 : 不存在于词向量中
# 確實 : 不存在于词向量中
# 這种 : 不存在于词向量中
# 三有 : 不存在于词向量中
# 天难 : 不存在于词向量中
# 赶让 : 不存在于词向量中
# 一所 : 不存在于词向量中
# 中慢 : 不存在于词向量中
# 怠慢 : 不存在于词向量中
# 2222222222222222222222222222222222 : 不存在于词向量中
# 表姐 : 不存在于词向量中
# 找求 : 不存在于词向量中
# 死去 : 不存在于词向量中
# 找点 : 不存在于词向量中
# 资料齐全 : 不存在于词向量中
# 货烂 : 不存在于词向量中
# 毛是 : 不存在于词向量中
# 能往 : 不存在于词向量中
# 7.18 : 不存在于词向量中
# 三文鱼 : 不存在于词向量中
# 送卫衣 : 不存在于词向量中
# 艰苦 : 不存在于词向量中
# 可可粉 : 不存在于词向量中
# 礼拜二 : 不存在于词向量中
# 跳出去 : 不存在于词向量中
# 价不 : 不存在于词向量中
# 帮盆友 : 不存在于词向量中
# 营销商 : 不存在于词向量中
# 掏友 : 不存在于词向量中
# 卖呆 : 不存在于词向量中
# 台次 : 不存在于词向量中
# 一千公里 : 不存在于词向量中
# 外调 : 不存在于词向量中
# 答题卡 : 不存在于词向量中
# 格信 : 不存在于词向量中
# 照完 : 不存在于词向量中
# 大鱼大肉 : 不存在于词向量中
# 吃惯 : 不存在于词向量中
# 青菜 : 不存在于词向量中
# 香是 : 不存在于词向量中
# 品不 : 不存在于词向量中
# 耐品 : 不存在于词向量中
# 外业 : 不存在于词向量中
# 刚买变 : 不存在于词向量中
# thiknpad : 不存在于词向量中
# t480 : 不存在于词向量中
# 项链 : 不存在于词向量中
# 11g : 不存在于词向量中
# 2.89 : 不存在于词向量中
# 有少少 : 不存在于词向量中
# 冰冰凉 : 不存在于词向量中
# 爽滑 : 不存在于词向量中
# 白玉无瑕 : 不存在于词向量中
# 包出 : 不存在于词向量中
# 小亏 : 不存在于词向量中
# 80G : 不存在于词向量中
# 锁个 : 不存在于词向量中
# 曾几何时 : 不存在于词向量中
# 从装 : 不存在于词向量中
# 萌新 : 不存在于词向量中
# 考机 : 不存在于词向量中
# cpu95 : 不存在于词向量中
# 强太 : 不存在于词向量中
# 整疯 : 不存在于词向量中
# 听响 : 不存在于词向量中
# 卡丝 : 不存在于词向量中
# 难上加难 : 不存在于词向量中
# 合格品 : 不存在于词向量中
# 我样 : 不存在于词向量中
# 拖够 : 不存在于词向量中
# 黑箱操作 : 不存在于词向量中
# 柔然 : 不存在于词向量中
# 虚有其表 : 不存在于词向量中
# 有设 : 不存在于词向量中
# 指感 : 不存在于词向量中
# 名益 : 不存在于词向量中
# 黑团 : 不存在于词向量中
# 条小 : 不存在于词向量中
# 心给 : 不存在于词向量中
# 录不进 : 不存在于词向量中
# 栏上 : 不存在于词向量中
# 设个 : 不存在于词向量中
# 卖成 : 不存在于词向量中
# 硬梆梆 : 不存在于词向量中
# 震裂 : 不存在于词向量中
# 胶胶 : 不存在于词向量中
# 接台 : 不存在于词向量中
# 加换 : 不存在于词向量中
# 酒味 : 不存在于词向量中
# safari : 不存在于词向量中
# 店干 : 不存在于词向量中
# 难辞其咎 : 不存在于词向量中
# 钱认 : 不存在于词向量中
# 得寸进尺 : 不存在于词向量中
# 配开 : 不存在于词向量中
# 这汉手 : 不存在于词向量中
# 我安卓里 : 不存在于词向量中
# 反京豆 : 不存在于词向量中
# 好菜 : 不存在于词向量中
# 小林 : 不存在于词向量中
# 态差 : 不存在于词向量中
# 热键 : 不存在于词向量中
# 过大牛 : 不存在于词向量中
# 摄主 : 不存在于词向量中
# 夏普 : 不存在于词向量中
# 脚大嘛 : 不存在于词向量中
# 虫儿 : 不存在于词向量中
# 卡糟 : 不存在于词向量中
# 真腊 : 不存在于词向量中
# 宽裕 : 不存在于词向量中
# 贫困山区 : 不存在于词向量中
# 家境 : 不存在于词向量中
# 勤工俭学 : 不存在于词向量中
# 中学生 : 不存在于词向量中
# 记在 : 不存在于词向量中
# 问路 : 不存在于词向量中
# 人笑 : 不存在于词向量中
# 刀片 : 不存在于词向量中
# 缠裹 : 不存在于词向量中
# 多缠 : 不存在于词向量中
# 保洁 : 不存在于词向量中
# 医保 : 不存在于词向量中
# 公历 : 不存在于词向量中
# 机老 : 不存在于词向量中
# 沚 : 不存在于词向量中
# 黑得 : 不存在于词向量中
# 紧迫感 : 不存在于词向量中
# 但接 : 不存在于词向量中
# 无通 : 不存在于词向量中
# 永济 : 不存在于词向量中
# 不称职 : 不存在于词向量中
# 健买过 : 不存在于词向量中
# 可取 : 不存在于词向量中
# 鞋根 : 不存在于词向量中
# 海报 : 不存在于词向量中
# 还酬 : 不存在于词向量中
# 诉说 : 不存在于词向量中
# 底儿 : 不存在于词向量中
# 字快 : 不存在于词向量中
# 双引擎 : 不存在于词向量中
# 自营商 : 不存在于词向量中
# 上百人 : 不存在于词向量中
# 斜入 : 不存在于词向量中
# 9499zx8 : 不存在于词向量中
# 火车站 : 不存在于词向量中
# 招拿去 : 不存在于词向量中
# vivox9plus : 不存在于词向量中
# へ : 不存在于词向量中
# 别论 : 不存在于词向量中
# 告吹 : 不存在于词向量中
# 说漏嘴 : 不存在于词向量中
# 说安卓用 : 不存在于词向量中
# 不防压 : 不存在于词向量中
# 茅坑 : 不存在于词向量中
# 死敌 : 不存在于词向量中
# 蔡司加 : 不存在于词向量中
# 持有 : 不存在于词向量中
# 取暖器 : 不存在于词向量中
# 塞住 : 不存在于词向量中
# 面看 : 不存在于词向量中
# 百般狡辩 : 不存在于词向量中
# 出而 : 不存在于词向量中
# 穿长 : 不存在于词向量中
# 过段 : 不存在于词向量中
# 脸线 : 不存在于词向量中
# 易清洗 : 不存在于词向量中
# 京豆后 : 不存在于词向量中
# 国产车 : 不存在于词向量中
# 油乎乎 : 不存在于词向量中
# 腥味 : 不存在于词向量中
# 弥漫着 : 不存在于词向量中
# 腥臭味 : 不存在于词向量中
# 一巴掌 : 不存在于词向量中
# 购买权 : 不存在于词向量中
# 肥人 : 不存在于词向量中
# 伸向 : 不存在于词向量中
# 倒地 : 不存在于词向量中
# 二星 : 不存在于词向量中
# 下人 : 不存在于词向量中
# 贴边 : 不存在于词向量中
# 手飞 : 不存在于词向量中
# 学到 : 不存在于词向量中
# 717G : 不存在于词向量中
# 哪门 : 不存在于词向量中
# 中逛 : 不存在于词向量中
# 到合 : 不存在于词向量中
# 帅哥哥 : 不存在于词向量中
# 递到 : 不存在于词向量中
# 价保下 : 不存在于词向量中
# 小殷 : 不存在于词向量中
# 没得评 : 不存在于词向量中
# 4.06 : 不存在于词向量中
# huawei : 不存在于词向量中
# 偏着 : 不存在于词向量中
# 正看 : 不存在于词向量中
# 金边 : 不存在于词向量中
# fitcard : 不存在于词向量中
# 50KB : 不存在于词向量中
# 孔太 : 不存在于词向量中
# 慎之慎 : 不存在于词向量中
# 灰白色 : 不存在于词向量中
# bao : 不存在于词向量中
# 1050t : 不存在于词向量中
# 玩惯 : 不存在于词向量中
# 象蜗牛 : 不存在于词向量中
# 楔形 : 不存在于词向量中
# 点缀 : 不存在于词向量中
# GT750M : 不存在于词向量中
# 合模线 : 不存在于词向量中
# Tf : 不存在于词向量中
# 照比 : 不存在于词向量中
# 楼层 : 不存在于词向量中
# 扁平化 : 不存在于词向量中
# 玩圣安地 : 不存在于词向量中
# 列斯 : 不存在于词向量中
# 一折 : 不存在于词向量中
# 黄金卡 : 不存在于词向量中
# 没折 : 不存在于词向量中
# dev : 不存在于词向量中
# 完必 : 不存在于词向量中
# 爽威威 : 不存在于词向量中
# 炫光晃 : 不存在于词向量中
# 简用 : 不存在于词向量中
# 托付给 : 不存在于词向量中
# 耍心眼 : 不存在于词向量中
# 亏得 : 不存在于词向量中
# 作响 : 不存在于词向量中
# 说太坑 : 不存在于词向量中
# 屁连 : 不存在于词向量中
# 梦婷超 : 不存在于词向量中
# 横流 : 不存在于词向量中
# 刺手 : 不存在于词向量中
# 四买个 : 不存在于词向量中
# 来要 : 不存在于词向量中
# 较前 : 不存在于词向量中
# DATO2 : 不存在于词向量中
# 千呼万唤 : 不存在于词向量中
# 买新出 : 不存在于词向量中
# 比样 : 不存在于词向量中
# 卡不死 : 不存在于词向量中
# 打牌 : 不存在于词向量中
# NX563J : 不存在于词向量中
# 假如能 : 不存在于词向量中
# 买用 : 不存在于词向量中
# 屏门 : 不存在于词向量中
# 会回 : 不存在于词向量中
# 长和窄 : 不存在于词向量中
# 北斗 : 不存在于词向量中
# 稍大点 : 不存在于词向量中
# 车机 : 不存在于词向量中
# 淡黄色 : 不存在于词向量中
# 甭想 : 不存在于词向量中
# 660cpu : 不存在于词向量中
# 怱 : 不存在于词向量中
# 悠人 : 不存在于词向量中
# 轻宜 : 不存在于词向量中
# 连为 : 不存在于词向量中
# 缝死 : 不存在于词向量中
# 搞开 : 不存在于词向量中
# 难顶 : 不存在于词向量中
# 洗一洗 : 不存在于词向量中
# 淡化 : 不存在于词向量中
# 闭不闭 : 不存在于词向量中
# 烦闲 : 不存在于词向量中
# 力快 : 不存在于词向量中
# 可换 : 不存在于词向量中
# 单刷 : 不存在于词向量中
# 劣势 : 不存在于词向量中
# 实费 : 不存在于词向量中
# 当月 : 不存在于词向量中
# 月租费 : 不存在于词向量中
# 查完 : 不存在于词向量中
# 后大赞 : 不存在于词向量中
# 可爽 : 不存在于词向量中
# 总放 : 不存在于词向量中
# 鼓个 : 不存在于词向量中
# 大包 : 不存在于词向量中
# 双刃剑 : 不存在于词向量中
# 鞋要 : 不存在于词向量中
# 正装鞋 : 不存在于词向量中
# 稍低 : 不存在于词向量中
# 傻白甜 : 不存在于词向量中
# 23686 : 不存在于词向量中
# 211377 : 不存在于词向量中
# 223450 : 不存在于词向量中
# OFFICE365 : 不存在于词向量中
# 太挫 : 不存在于词向量中
# 159385360 : 不存在于词向量中
# 203350WIN : 不存在于词向量中
# 左天 : 不存在于词向量中
# 完成度 : 不存在于词向量中
# 某族 : 不存在于词向量中
# 815 : 不存在于词向量中
# 抢下 : 不存在于词向量中
# 强军 : 不存在于词向量中
# name : 不存在于词向量中
# 痣 : 不存在于词向量中
# 按普 : 不存在于词向量中
# 攻会 : 不存在于词向量中
# 前所未见 : 不存在于词向量中
# 担惊受怕 : 不存在于词向量中
# 不识货 : 不存在于词向量中
# 有歌 : 不存在于词向量中
# 貨 : 不存在于词向量中
# 一觉 : 不存在于词向量中
# 不太得 : 不存在于词向量中
# 创办 : 不存在于词向量中
# CDE : 不存在于词向量中
# 课题 : 不存在于词向量中
# 2m3m : 不存在于词向量中
# 变样 : 不存在于词向量中
# 键锁屏 : 不存在于词向量中
# 他试 : 不存在于词向量中
# 不对款 : 不存在于词向量中
# 再解 : 不存在于词向量中
# 出苦 : 不存在于词向量中
# 耗死 : 不存在于词向量中
# 没暖用 : 不存在于词向量中
# 刚买留 : 不存在于词向量中
# 太堵 : 不存在于词向量中
# 深褐色 : 不存在于词向量中
# 扫到 : 不存在于词向量中
# 稻草 : 不存在于词向量中
# 写真 : 不存在于词向量中
# 黑漆漆 : 不存在于词向量中
# 年过半百 : 不存在于词向量中
# 5V1.5 : 不存在于词向量中
# 连句 : 不存在于词向量中
# 竟能 : 不存在于词向量中
# 糖果 : 不存在于词向量中
# 食品类 : 不存在于词向量中
# 5x6x : 不存在于词向量中
# 网看 : 不存在于词向量中
# 差换个 : 不存在于词向量中
# 死无对证 : 不存在于词向量中
# 笑嘻嘻 : 不存在于词向量中
# 太非 : 不存在于词向量中
# 买不来 : 不存在于词向量中
# 粘着 : 不存在于词向量中
# 东奔西跑 : 不存在于词向量中
# 白圈 : 不存在于词向量中
# 员前 : 不存在于词向量中
# 附代 : 不存在于词向量中
# 做碎 : 不存在于词向量中
# 浴霸 : 不存在于词向量中
# 买卫衣 : 不存在于词向量中
# 021 : 不存在于词向量中
# 截止日 : 不存在于词向量中
# 扫不起 : 不存在于词向量中
# 王府井 : 不存在于词向量中
# 病秧子 : 不存在于词向量中
# 淡蓝 : 不存在于词向量中
# 那修 : 不存在于词向量中
# 解需 : 不存在于词向量中
# 屏太差 : 不存在于词向量中
# 最可误 : 不存在于词向量中
# 之事 : 不存在于词向量中
# 对天发誓 : 不存在于词向量中
# 决无 : 不存在于词向量中
# 买安卓 : 不存在于词向量中
# 货开 : 不存在于词向量中
# 少掉 : 不存在于词向量中
# 经由 : 不存在于词向量中
# 有车 : 不存在于词向量中
# 天内出 : 不存在于词向量中
# 湘符 : 不存在于词向量中
# 比奇 : 不存在于词向量中
# 版宿水 : 不存在于词向量中
# 送进去 : 不存在于词向量中
# 先不作 : 不存在于词向量中
# 门要 : 不存在于词向量中
# fx73vd : 不存在于词向量中
# 价来 : 不存在于词向量中
# 4098 : 不存在于词向量中
# 还得加 : 不存在于词向量中
# 二维 : 不存在于词向量中
# 画着 : 不存在于词向量中
# 图鲁 : 不存在于词向量中
# 拉手 : 不存在于词向量中
# 过歉 : 不存在于词向量中
# 计步器 : 不存在于词向量中
# 100youhuijuan : 不存在于词向量中
# 一尘不染 : 不存在于词向量中
# 半后 : 不存在于词向量中
# 擅 : 不存在于词向量中
# 洗过来 : 不存在于词向量中
# 算啦 : 不存在于词向量中
# 资询 : 不存在于词向量中
# 不安全感 : 不存在于词向量中
# 隐身 : 不存在于词向量中
# 臂袋 : 不存在于词向量中
# 放尽 : 不存在于词向量中
# 物统 : 不存在于词向量中
# APPLEMACPRO : 不存在于词向量中
# 神快 : 不存在于词向量中
# 蛮软 : 不存在于词向量中
# 口及 : 不存在于词向量中
# 轮廓 : 不存在于词向量中
# 那破音 : 不存在于词向量中
# 不惯 : 不存在于词向量中
# 轻掉 : 不存在于词向量中
# ro : 不存在于词向量中
# ot : 不存在于词向量中
# 没先 : 不存在于词向量中
# 感轻 : 不存在于词向量中
# 软合 : 不存在于词向量中
# 刷价花 : 不存在于词向量中
# 卡打个 : 不存在于词向量中
# 雷声 : 不存在于词向量中
# 脱裤子 : 不存在于词向量中
# 蛮长 : 不存在于词向量中
# 18.08 : 不存在于词向量中
# 本质区别 : 不存在于词向量中
# 千里之堤 : 不存在于词向量中
# 溃于蚁穴 : 不存在于词向量中
# 买假 : 不存在于词向量中
# 伸请 : 不存在于词向量中
# 水为 : 不存在于词向量中
# 返修率 : 不存在于词向量中
# 昙花一现 : 不存在于词向量中
# 双给 : 不存在于词向量中
# 补交 : 不存在于词向量中
# 我顶 : 不存在于词向量中
# 搞点 : 不存在于词向量中
# 购无语 : 不存在于词向量中
# 四项 : 不存在于词向量中
# 28s : 不存在于词向量中
# 底价 : 不存在于词向量中
# 一未 : 不存在于词向量中
# 脚不痛 : 不存在于词向量中
# 抢满 : 不存在于词向量中
# 没刚 : 不存在于词向量中
# 千零蚊 : 不存在于词向量中
# 风口 : 不存在于词向量中
# 古驰 : 不存在于词向量中
# 振动模式 : 不存在于词向量中
# 账户就 : 不存在于词向量中
# 转个 : 不存在于词向量中
# 外中 : 不存在于词向量中
# 好全 : 不存在于词向量中
# 回城 : 不存在于词向量中
# 条例 : 不存在于词向量中
# 码发过 : 不存在于词向量中
# 内网 : 不存在于词向量中
# 后备 : 不存在于词向量中
# 可大 : 不存在于词向量中
# 继承 : 不存在于词向量中
# 光亮度 : 不存在于词向量中
# 太不道 : 不存在于词向量中
# 十七八天 : 不存在于词向量中
# 五六条 : 不存在于词向量中
# 小炫 : 不存在于词向量中
# 精英 : 不存在于词向量中
# 帮罗 : 不存在于词向量中
# 吞诺记 : 不存在于词向量中
# 惨案 : 不存在于词向量中
# 信用度 : 不存在于词向量中
# 部坏 : 不存在于词向量中
# 帮不上 : 不存在于词向量中
# 出响 : 不存在于词向量中
# 打电 : 不存在于词向量中
# 磁力 : 不存在于词向量中
# Z11MAX : 不存在于词向量中
# 穿足面 : 不存在于词向量中
# 不堤 : 不存在于词向量中
# 价格低廉 : 不存在于词向量中
# 吴论 : 不存在于词向量中
# 认认真真 : 不存在于词向量中
# 靠右 : 不存在于词向量中
# 由小及 : 不存在于词向量中
# 大厦将倾 : 不存在于词向量中
# idiot : 不存在于词向量中
# 压出 : 不存在于词向量中
# 发的券 : 不存在于词向量中
# 券是 : 不存在于词向量中
# 真心实意 : 不存在于词向量中
# 照不到 : 不存在于词向量中
# 曾经沧海 : 不存在于词向量中
# 巫山 : 不存在于词向量中
# 取次 : 不存在于词向量中
# 花丛 : 不存在于词向量中
# 半缘 : 不存在于词向量中
# 修道 : 不存在于词向量中
# 半缘君 : 不存在于词向量中
# 洗个 : 不存在于词向量中
# 货拿 : 不存在于词向量中
# 略偏 : 不存在于词向量中
# 打弯 : 不存在于词向量中
# out : 不存在于词向量中
# 永无 : 不存在于词向量中
# 手拉手 : 不存在于词向量中
# 考虑不周 : 不存在于词向量中
# 复出 : 不存在于词向量中
# 老同志 : 不存在于词向量中
# 7PLUS : 不存在于词向量中
# 洗脚 : 不存在于词向量中
# 部買 : 不存在于词向量中
# 顯示 : 不存在于词向量中
# 換貨要 : 不存在于词向量中
# 退貨 : 不存在于词向量中
# 單還 : 不存在于词向量中
# 快點 : 不存在于词向量中
# 這手機 : 不存在于词向量中
# 適合 : 不存在于词向量中
# 存大 : 不存在于词向量中
# 過多 : 不存在于词向量中
# 先加 : 不存在于词向量中
# 期息费 : 不存在于词向量中
# 簇拥 : 不存在于词向量中
# 住户 : 不存在于词向量中
# 电表 : 不存在于词向量中
# 偷换 : 不存在于词向量中
# 会整 : 不存在于词向量中
# 线才行 : 不存在于词向量中
# 看起装 : 不存在于词向量中
# 鸡边 : 不存在于词向量中
# 闷气 : 不存在于词向量中
# 1379 : 不存在于词向量中
# n4X : 不存在于词向量中
# 风吹 : 不存在于词向量中
# 全塑 : 不存在于词向量中
# 我知 : 不存在于词向量中
# 沒什麼 : 不存在于词向量中
# 缺點 : 不存在于词向量中
# 聯想 : 不存在于词向量中
# 自帶 : 不存在于词向量中
# 太霸 : 不存在于词向量中
# 卸載 : 不存在于词向量中
# 整體 : 不存在于词向量中
# 開多 : 不存在于词向量中
# 不會卡 : 不存在于词向量中
# 面为 : 不存在于词向量中
# 有多深 : 不存在于词向量中
# 做键 : 不存在于词向量中
# 涡 : 不存在于词向量中
# 卖步 : 不存在于词向量中
# 少走弯路 : 不存在于词向量中
# 教给 : 不存在于词向量中
# 储蓄卡 : 不存在于词向量中
# 广而告之 : 不存在于词向量中
# 心甘情愿 : 不存在于词向量中
# 日记本 : 不存在于词向量中
# 地多 : 不存在于词向量中
# 痘 : 不存在于词向量中
# 卢本伟 : 不存在于词向量中
# oppoa57 : 不存在于词向量中
# 穿来 : 不存在于词向量中
# ubuntu17.10 : 不存在于词向量中
# 神卷 : 不存在于词向量中
# 卡孔 : 不存在于词向量中
# 挺高来 : 不存在于词向量中
# 空卡 : 不存在于词向量中
# 葡 : 不存在于词向量中
# 友好关系 : 不存在于词向量中
# 晚送 : 不存在于词向量中
# 折子 : 不存在于词向量中
# 屏买 : 不存在于词向量中
# 法官 : 不存在于词向量中
# 判案 : 不存在于词向量中
# 冤假错案 : 不存在于词向量中
# 东滴 : 不存在于词向量中
# 西滴 : 不存在于词向量中
# 欠钱 : 不存在于词向量中
# wif : 不存在于词向量中
# 七十六 : 不存在于词向量中
# 境况 : 不存在于词向量中
# 会当 : 不存在于词向量中
# 钱出 : 不存在于词向量中
# 小楚 : 不存在于词向量中
# 言谈 : 不存在于词向量中
# 实乃 : 不存在于词向量中
# 之良品 : 不存在于词向量中
# 漏油 : 不存在于词向量中
# 于心不忍 : 不存在于词向量中
# 情以 : 不存在于词向量中
# 何堪 : 不存在于词向量中
# 随配 : 不存在于词向量中
# 线够 : 不存在于词向量中
# 坦诚 : 不存在于词向量中
# 八折 : 不存在于词向量中
# 封掉 : 不存在于词向量中
# 小珠 : 不存在于词向量中
# 唯我独尊 : 不存在于词向量中
# 低邦板 : 不存在于词向量中
# 2Windows : 不存在于词向量中
# Hello : 不存在于词向量中
# 滴快 : 不存在于词向量中
# 产品检验 : 不存在于词向量中
# 更年期 : 不存在于词向量中
# 店脑 : 不存在于词向量中
# 重创 : 不存在于词向量中
# 背书 : 不存在于词向量中
# 外贸部 : 不存在于词向量中
# 分百 : 不存在于词向量中
# 64663 : 不存在于词向量中
# 后盖亮 : 不存在于词向量中
# ChinaJoy : 不存在于词向量中
# 展台 : 不存在于词向量中
# 144Hz : 不存在于词向量中
# 形白灯 : 不存在于词向量中
# 类肤 : 不存在于词向量中
# mDP : 不存在于词向量中
# 60Hz : 不存在于词向量中
# 精悍 : 不存在于词向量中
# 2160 : 不存在于词向量中
# 1080FHD : 不存在于词向量中
# 身临其境 : 不存在于词向量中
# 有破响 : 不存在于词向量中
# 老铁别 : 不存在于词向量中
# 韩货 : 不存在于词向量中
# 值几钱 : 不存在于词向量中
# ATC705 : 不存在于词向量中
# N50 : 不存在于词向量中
# G3250 : 不存在于词向量中
# Win8.1 : 不存在于词向量中
# 盲打 : 不存在于词向量中
# 23333 : 不存在于词向量中
# 礼拜三 : 不存在于词向量中
# 周整 : 不存在于词向量中
# 基督 : 不存在于词向量中
# 昭苏 : 不存在于词向量中
# 110.122 : 不存在于词向量中
# 还关 : 不存在于词向量中
# 去往 : 不存在于词向量中
# 输光 : 不存在于词向量中
# 裤缝 : 不存在于词向量中
# 话别 : 不存在于词向量中
# 货比 : 不存在于词向量中
# 还怕 : 不存在于词向量中
# 大试 : 不存在于词向量中
# 比狗 : 不存在于词向量中
# 达多收 : 不存在于词向量中
# 恍恍荡荡 : 不存在于词向量中
# 又定 : 不存在于词向量中
# 4pro : 不存在于词向量中
# MATES : 不存在于词向量中
# 帮別 : 不存在于词向量中
# 秉持 : 不存在于词向量中
# 更上一层楼 : 不存在于词向量中
# fps70 : 不存在于词向量中
# 货打 : 不存在于词向量中
# 长胖 : 不存在于词向量中
# 0k : 不存在于词向量中
# 座椅 : 不存在于词向量中
# 大昂 : 不存在于词向量中
# 特么闻 : 不存在于词向量中
# 游都会 : 不存在于词向量中
# 小丑 : 不存在于词向量中
# 招人 : 不存在于词向量中
# m4 : 不存在于词向量中
# 影彩 : 不存在于词向量中
# 桑蚕丝 : 不存在于词向量中
# 时选 : 不存在于词向量中
# 遮上 : 不存在于词向量中
# 携帶 : 不存在于词向量中
# 專門作 : 不存在于词向量中
# 偶爾 : 不存在于词向量中
# 視頻 : 不存在于词向量中
# 覺得 : 不存在于词向量中
# 電量 : 不存在于词向量中
# 現 : 不存在于词向量中
# 讚 : 不存在于词向量中
# 開 : 不存在于词向量中
# 好运气 : 不存在于词向量中
# 火麒麟 : 不存在于词向量中
# 轰鸣 : 不存在于词向量中
# 送家 : 不存在于词向量中
# 热时 : 不存在于词向量中
# 嫩嫩的 : 不存在于词向量中
# 无数回 : 不存在于词向量中
# 申冤 : 不存在于词向量中
# 胶质 : 不存在于词向量中
# 短退 : 不存在于词向量中
# 珠 : 不存在于词向量中
# 1.93 : 不存在于词向量中
# 378 : 不存在于词向量中
# 自动重拨 : 不存在于词向量中
# 坐席 : 不存在于词向量中
# 掐定 : 不存在于词向量中
# 爱修 : 不存在于词向量中
# 下山 : 不存在于词向量中
# 踏足 : 不存在于词向量中
# 亮痕 : 不存在于词向量中
# 烫发 : 不存在于词向量中
# 吸毛吸 : 不存在于词向量中
# 励害 : 不存在于词向量中
# 换醒键 : 不存在于词向量中
# 扭花 : 不存在于词向量中
# 包电 : 不存在于词向量中
# 手東 : 不存在于词向量中
# 地花 : 不存在于词向量中
# 苦恼 : 不存在于词向量中
# 不耐管 : 不存在于词向量中
# 无坏 : 不存在于词向量中
# 小白圈 : 不存在于词向量中
# 那尿性 : 不存在于词向量中
# 歪瑞 : 不存在于词向量中
# 故都 : 不存在于词向量中
# 血汗 : 不存在于词向量中
# 针装卡 : 不存在于词向量中
# 加触 : 不存在于词向量中
# 黑越 : 不存在于词向量中
# b250 : 不存在于词向量中
# 口太 : 不存在于词向量中
# 机够 : 不存在于词向量中
# 几斤几两 : 不存在于词向量中
# 所据 : 不存在于词向量中
# 分摊 : 不存在于词向量中
# 管生 : 不存在于词向量中
# 真几八是 : 不存在于词向量中
# 给晨 : 不存在于词向量中
# 纪念品 : 不存在于词向量中
# 0Ppo : 不存在于词向量中
# 一千两百 : 不存在于词向量中
# 螺纹 : 不存在于词向量中
# 保护价 : 不存在于词向量中
# 破铜烂 : 不存在于词向量中
# 17999 : 不存在于词向量中
# 亏心 : 不存在于词向量中
# 146G : 不存在于词向量中
# 款下 : 不存在于词向量中
# 小花样 : 不存在于词向量中
# 暗亏 : 不存在于词向量中
# 默许 : 不存在于词向量中
# 剪小卡 : 不存在于词向量中
# 沒磕过 : 不存在于词向量中
# 全险 : 不存在于词向量中
# 朝阳 : 不存在于词向量中
# 2889 : 不存在于词向量中
# 芊 : 不存在于词向量中
# 软面 : 不存在于词向量中
# 卷脚 : 不存在于词向量中
# 空旷 : 不存在于词向量中
# 换新保 : 不存在于词向量中
# 脱脱 : 不存在于词向量中
# 地一 : 不存在于词向量中
# 令人遗憾 : 不存在于词向量中
# 金会 : 不存在于词向量中
# 贴到 : 不存在于词向量中
# 苏 : 不存在于词向量中
# 那灯 : 不存在于词向量中
# 脚膜 : 不存在于词向量中
# 没塞 : 不存在于词向量中
# 没漂 : 不存在于词向量中
# 难满 : 不存在于词向量中
# 满篇 : 不存在于词向量中
# 冬鞋 : 不存在于词向量中
# 稳准 : 不存在于词向量中
# 壹佰是 : 不存在于词向量中
# 开时 : 不存在于词向量中
# 用户注册 : 不存在于词向量中
# 1X : 不存在于词向量中
# 服务上门 : 不存在于词向量中
# 加工厂 : 不存在于词向量中
# 做安卓 : 不存在于词向量中
# 一帮人 : 不存在于词向量中
# 国家机器 : 不存在于词向量中
# 几日 : 不存在于词向量中
# 年别 : 不存在于词向量中
# 4000mh : 不存在于词向量中
# 通变 : 不存在于词向量中
# 身双卡 : 不存在于词向量中
# 走下坡 : 不存在于词向量中
# CP : 不存在于词向量中
# 墨子 : 不存在于词向量中
# 来列 : 不存在于词向量中
# 热要 : 不存在于词向量中
# 多喝水 : 不存在于词向量中
# 注意安全 : 不存在于词向量中
# 票顶 : 不存在于词向量中
# 跳个 : 不存在于词向量中
# 不漏 : 不存在于词向量中
# 更软 : 不存在于词向量中
# orz : 不存在于词向量中
# 查字典 : 不存在于词向量中
# 叽 : 不存在于词向量中
# 卖坏 : 不存在于词向量中
# 不同于 : 不存在于词向量中
# 没放 : 不存在于词向量中
# 累蒙 : 不存在于词向量中
# 扣下来 : 不存在于词向量中
# 空到 : 不存在于词向量中
# 位弄成 : 不存在于词向量中
# 龌 : 不存在于词向量中
# 蹉 : 不存在于词向量中
# 5588 : 不存在于词向量中
# 脚弓处 : 不存在于词向量中
# 演出票 : 不存在于词向量中
# 疾步 : 不存在于词向量中
# 装问 : 不存在于词向量中
# Ie : 不存在于词向量中
# 低版本 : 不存在于词向量中
# 一无 : 不存在于词向量中
# 还会范 : 不存在于词向量中
# 下会 : 不存在于词向量中
# 说国行 : 不存在于词向量中
# 晦气 : 不存在于词向量中
# 没睁大点 : 不存在于词向量中
# 为时已晚 : 不存在于词向量中
# 捧出来 : 不存在于词向量中
# 惯有 : 不存在于词向量中
# 撬后 : 不存在于词向量中
# 洗干 : 不存在于词向量中
# 整过 : 不存在于词向量中
# 撩起 : 不存在于词向量中
# l28G : 不存在于词向量中
# 卡测 : 不存在于词向量中
# 撬动 : 不存在于词向量中
# yidiWIFI : 不存在于词向量中
# 塑胶套 : 不存在于词向量中
# 退返 : 不存在于词向量中
# 开大音 : 不存在于词向量中
# 暂新 : 不存在于词向量中
# 第二名 : 不存在于词向量中
# 好区 : 不存在于词向量中
# 很感 : 不存在于词向量中
# 进洞 : 不存在于词向量中
# 刚要 : 不存在于词向量中
# 拼团 : 不存在于词向量中
# 这京准 : 不存在于词向量中
# 推掉 : 不存在于词向量中
# 时过 : 不存在于词向量中
# 小袋装 : 不存在于词向量中
# 整弯 : 不存在于词向量中
# 系统还原 : 不存在于词向量中
# 看全 : 不存在于词向量中
# 隔死 : 不存在于词向量中
# 屏时 : 不存在于词向量中
# 猛用 : 不存在于词向量中
# ove : 不存在于词向量中
# 70FPS : 不存在于词向量中
# 店强 : 不存在于词向量中
# 纹儿 : 不存在于词向量中
# CDR : 不存在于词向量中
# 几了 : 不存在于词向量中
# 3200ma : 不存在于词向量中
# 那么出色 : 不存在于词向量中
# 可察觉 : 不存在于词向量中
# 非带 : 不存在于词向量中
# 全上 : 不存在于词向量中
# 私聊 : 不存在于词向量中
# 煽动 : 不存在于词向量中
# 榜 : 不存在于词向量中
# 洗水棉 : 不存在于词向量中
# 八子 : 不存在于词向量中
# 新船 : 不存在于词向量中
# 有白屏 : 不存在于词向量中
# 毛有 : 不存在于词向量中
# 也积 : 不存在于词向量中
# 摸个 : 不存在于词向量中
# 几十遍 : 不存在于词向量中
# 肝 : 不存在于词向量中
# 置办 : 不存在于词向量中
# 我清 : 不存在于词向量中
# 鞋长 : 不存在于词向量中
# 多冲 : 不存在于词向量中
# 請 : 不存在于词向量中
# 幫 : 不存在于词向量中
# 纯在 : 不存在于词向量中
# 低至 : 不存在于词向量中
# 删贴 : 不存在于词向量中
# 逸致 : 不存在于词向量中
# 蚊机 : 不存在于词向量中
# 屁狗 : 不存在于词向量中
# 标到 : 不存在于词向量中
# 白掉 : 不存在于词向量中
# not4x : 不存在于词向量中
# 新套 : 不存在于词向量中
# 栏干 : 不存在于词向量中
# 主见 : 不存在于词向量中
# 学上 : 不存在于词向量中
# 异想 : 不存在于词向量中
# 够慢 : 不存在于词向量中
# 笨蛋 : 不存在于词向量中
# 橡皮擦 : 不存在于词向量中
# Liteon : 不存在于词向量中
# 系统启动 : 不存在于词向量中
# 转太高 : 不存在于词向量中
# 根号 : 不存在于词向量中
# 游器 : 不存在于词向量中
# 称因 : 不存在于词向量中
# 无法说明 : 不存在于词向量中
# 阿鹿 : 不存在于词向量中
# 男女老少 : 不存在于词向量中
# 品种齐全 : 不存在于词向量中
# 宅 : 不存在于词向量中
# 动动手 : 不存在于词向量中
# 25W : 不存在于词向量中
# Q5plus : 不存在于词向量中
# 挺狂 : 不存在于词向量中
# 停站 : 不存在于词向量中
# 六倍 : 不存在于词向量中
# 点早 : 不存在于词向量中
# office360 : 不存在于词向量中
# 试用装 : 不存在于词向量中
# 20180523 : 不存在于词向量中
# 20180601 : 不存在于词向量中
# 五四 : 不存在于词向量中
# 耍尼跌 : 不存在于词向量中
# 算盘 : 不存在于词向量中
# 敲得 : 不存在于词向量中
# 铛铛 : 不存在于词向量中
# 半变 : 不存在于词向量中
# 仪是 : 不存在于词向量中
# 上大一 : 不存在于词向量中
# 爱卡顿 : 不存在于词向量中
# 不高哟 : 不存在于词向量中
# 人不太 : 不存在于词向量中
# 价和非 : 不存在于词向量中
# 天拿水 : 不存在于词向量中
# 雾痕 : 不存在于词向量中
# 12h : 不存在于词向量中
# 7700HQ : 不存在于词向量中
# GTX1050 : 不存在于词向量中
# 喇叭口 : 不存在于词向量中
# 朝下 : 不存在于词向量中
# 插好 : 不存在于词向量中
# 自作自受 : 不存在于词向量中
# 国外软件 : 不存在于词向量中
# 黑过 : 不存在于词向量中
# 久等 : 不存在于词向量中
# 钱加 : 不存在于词向量中
# 蒙圈 : 不存在于词向量中
# widows10 : 不存在于词向量中
# 略宽 : 不存在于词向量中
# 炙手 : 不存在于词向量中
# 水占 : 不存在于词向量中
# 解秒 : 不存在于词向量中
# 时发 : 不存在于词向量中
# 评在 : 不存在于词向量中
# 测试方法 : 不存在于词向量中
# 向外 : 不存在于词向量中
# 10690934334186 : 不存在于词向量中
# 17794612042 : 不存在于词向量中
# 上买东 : 不存在于词向量中
# 不买卡 : 不存在于词向量中
# 刷剧 : 不存在于词向量中
# 追番 : 不存在于词向量中
# 124 : 不存在于词向量中
# △ : 不存在于词向量中
# 压素 : 不存在于词向量中
# 相差近 : 不存在于词向量中
# 总觉 : 不存在于词向量中
# 热诚 : 不存在于词向量中
# 评荣 : 不存在于词向量中
# 超神 : 不存在于词向量中
# 小星 : 不存在于词向量中
# 歌卡 : 不存在于词向量中
# 饶恕 : 不存在于词向量中
# 6.13 : 不存在于词向量中
# 线脚 : 不存在于词向量中
# 火焰 : 不存在于词向量中
# 如动图 : 不存在于词向量中
# 夹得 : 不存在于词向量中
# 折成 : 不存在于词向量中
# 坚信不疑 : 不存在于词向量中
# 该次 : 不存在于词向量中
# 九百九十九 : 不存在于词向量中
# 圈套 : 不存在于词向量中
# 中计 : 不存在于词向量中
# 鞋码准 : 不存在于词向量中
# 烫个 : 不存在于词向量中
# 疵点 : 不存在于词向量中
# 老断 : 不存在于词向量中
# 173 : 不存在于词向量中
# 80kg : 不存在于词向量中
# 臀围 : 不存在于词向量中
# 围 : 不存在于词向量中
# 能泛 : 不存在于词向量中
# 用发 : 不存在于词向量中
# 救一救 : 不存在于词向量中
# 腳合適 : 不存在于词向量中
# 耻 : 不存在于词向量中
# 袒护 : 不存在于词向量中
# 一揭 : 不存在于词向量中
# 化学武器 : 不存在于词向量中
# 但现 : 不存在于词向量中
# 钱裤 : 不存在于词向量中
# 亮些 : 不存在于词向量中
# 暗些 : 不存在于词向量中
# 充次 : 不存在于词向量中
# 被誉为 : 不存在于词向量中
# nove3i : 不存在于词向量中
# 哨声 : 不存在于词向量中
# 低沉 : 不存在于词向量中
# 半秒 : 不存在于词向量中
# 二段 : 不存在于词向量中
# 大壳 : 不存在于词向量中
# 帅锅 : 不存在于词向量中
# 七双 : 不存在于词向量中
# 风轻云淡 : 不存在于词向量中
# mayu : 不存在于词向量中
# 3gram : 不存在于词向量中
# 版上 : 不存在于词向量中
# 研讨会 : 不存在于词向量中
# 欲罢不能 : 不存在于词向量中
# 捐步 : 不存在于词向量中
# 京港 : 不存在于词向量中
# 拉力赛 : 不存在于词向量中
# 其乐无穷 : 不存在于词向量中
# 上物 : 不存在于词向量中
# 赵月 : 不存在于词向量中
# 时人 : 不存在于词向量中
# 键会卡 : 不存在于词向量中
# 渗透 : 不存在于词向量中
# 扩散 : 不存在于词向量中
# 走进 : 不存在于词向量中
# 以品 : 不存在于词向量中
# 沙漠 : 不存在于词向量中
# 摔打 : 不存在于词向量中
# 加快速度 : 不存在于词向量中
# 六三 : 不存在于词向量中
# 六零 : 不存在于词向量中
# 尘点 : 不存在于词向量中
# 还原成 : 不存在于词向量中
# 退仓货 : 不存在于词向量中
# 亲薄 : 不存在于词向量中
# 里加 : 不存在于词向量中
# 入群 : 不存在于词向量中
# show : 不存在于词向量中
# 粘哒 : 不存在于词向量中
# 周就坏 : 不存在于词向量中
# 逃包 : 不存在于词向量中
# 誉 : 不存在于词向量中
# 滥竽充数 : 不存在于词向量中
# 没吹 : 不存在于词向量中
# 这图 : 不存在于词向量中
# 不闭 : 不存在于词向量中
# 恋恋不舍 : 不存在于词向量中
# 武功 : 不存在于词向量中
# 无坚不摧 : 不存在于词向量中
# 唯快 : 不存在于词向量中
# 哪一天 : 不存在于词向量中
# 匹敌 : 不存在于词向量中
# 机查 : 不存在于词向量中
# 奸诈 : 不存在于词向量中
# 机还算 : 不存在于词向量中
# 存好 : 不存在于词向量中
# 舒造 : 不存在于词向量中
# 广告单 : 不存在于词向量中
# 领圈 : 不存在于词向量中
# 实用工具 : 不存在于词向量中
# mode : 不存在于词向量中
# 上月底 : 不存在于词向量中
# air256G : 不存在于词向量中
# 最迟 : 不存在于词向量中
# 綦 : 不存在于词向量中
# 绽放 : 不存在于词向量中
# trash : 不存在于词向量中
# 3140 : 不存在于词向量中
# 商都 : 不存在于词向量中
# 有收 : 不存在于词向量中
# 斩 : 不存在于词向量中
# 小王子 : 不存在于词向量中
# 收之蒙灰 : 不存在于词向量中
# 边胶 : 不存在于词向量中
# 工场 : 不存在于词向量中
# 真臭 : 不存在于词向量中
# 擦鞋 : 不存在于词向量中
# 黑阴 : 不存在于词向量中
# 整烂 : 不存在于词向量中
# 电话录音 : 不存在于词向量中
# 连编 : 不存在于词向量中
# 扯谎 : 不存在于词向量中
# 2345 : 不存在于词向量中
# 1139 : 不存在于词向量中
# 全黄 : 不存在于词向量中
# 点店 : 不存在于词向量中
# TFT : 不存在于词向量中
# 奖给 : 不存在于词向量中
# 老主顾 : 不存在于词向量中
# 加绒会 : 不存在于词向量中
# 转角 : 不存在于词向量中
# 买陀 : 不存在于词向量中
# 去安兔 : 不存在于词向量中
# 太乐色 : 不存在于词向量中
# 鞋重 : 不存在于词向量中
# 赐教 : 不存在于词向量中
# 单员 : 不存在于词向量中
# 太昏 : 不存在于词向量中
# appleID : 不存在于词向量中
# 真挺重 : 不存在于词向量中
# 网坏 : 不存在于词向量中
# 真低 : 不存在于词向量中
# 裂得 : 不存在于词向量中
# 号取 : 不存在于词向量中
# 散场 : 不存在于词向量中
# E3 : 不存在于词向量中
# 玩不过来 : 不存在于词向量中
# s3 : 不存在于词向量中
# 轻游党 : 不存在于词向量中
# 喊话 : 不存在于词向量中
# 变大才行 : 不存在于词向量中
# 大幕 : 不存在于词向量中
# 录不上 : 不存在于词向量中
# 先屯 : 不存在于词向量中
# 感给 : 不存在于词向量中
# 主动权 : 不存在于词向量中
# 接着就是 : 不存在于词向量中
# 连降 : 不存在于词向量中
# 特显长 : 不存在于词向量中
# 逼玩应 : 不存在于词向量中
# 影象 : 不存在于词向量中
# 定焦 : 不存在于词向量中
# 冷藏 : 不存在于词向量中
# 闪快 : 不存在于词向量中
# 另具 : 不存在于词向量中
# 地为 : 不存在于词向量中
# 还产 : 不存在于词向量中
# 贰佰元 : 不存在于词向量中
# mx6 : 不存在于词向量中
# 条懒 : 不存在于词向量中
# UHD620 : 不存在于词向量中
# CUDA : 不存在于词向量中
# XTU : 不存在于词向量中
# 600p : 不存在于词向量中
# OEM : 不存在于词向量中
# 1866MHz : 不存在于词向量中
# 口满速 : 不存在于词向量中
# 120M : 不存在于词向量中
# 满速 : 不存在于词向量中
# 别胡说 : 不存在于词向量中
# 破本 : 不存在于词向量中
# 绝大 : 不存在于词向量中
# 两者之间 : 不存在于词向量中
# 尿布 : 不存在于词向量中
# 勾结 : 不存在于词向量中
# 来试 : 不存在于词向量中
# 相伴 : 不存在于词向量中
# 璀璨 : 不存在于词向量中
# 透明板 : 不存在于词向量中
# 拔坏 : 不存在于词向量中
# 置气 : 不存在于词向量中
# 六十多岁 : 不存在于词向量中
# 还生 : 不存在于词向量中
# 粘毛纸 : 不存在于词向量中
# 蜡纸 : 不存在于词向量中
# 牛到 : 不存在于词向量中
# 菊花 : 不存在于词向量中
# 放乐视 : 不存在于词向量中
# 有顿 : 不存在于词向量中
# 手机玩家 : 不存在于词向量中
# 服装店 : 不存在于词向量中
# qnimd : 不存在于词向量中
# 这档 : 不存在于词向量中
# 参考价格 : 不存在于词向量中
# 说东说西 : 不存在于词向量中
# 有漆 : 不存在于词向量中
# 利用微 : 不存在于词向量中
# 博 : 不存在于词向量中
# 5798 : 不存在于词向量中
# 偷用 : 不存在于词向量中
# 王八蛋 : 不存在于词向量中
# 貴 : 不存在于词向量中
# 慕名而来 : 不存在于词向量中
# 遛个 : 不存在于词向量中
# 弯回来 : 不存在于词向量中
# 設計師 : 不存在于词向量中
# 隔儿 : 不存在于词向量中
# 取到 : 不存在于词向量中
# 次旺 : 不存在于词向量中
# 卄 : 不存在于词向量中
# 前邦子 : 不存在于词向量中
# 哲学思想 : 不存在于词向量中
# 无不 : 不存在于词向量中
# 善行 : 不存在于词向量中
# 说服力 : 不存在于词向量中
# 治国 : 不存在于词向量中
# 理国 : 不存在于词向量中
# 哲学 : 不存在于词向量中
# 指导思想 : 不存在于词向量中
# 邓小平 : 不存在于词向量中
# 巨型 : 不存在于词向量中
# 相通 : 不存在于词向量中
# 任总对 : 不存在于词向量中
# 烹饪 : 不存在于词向量中
# 劳动 : 不存在于词向量中
# 高位 : 不存在于词向量中
# 道德经 : 不存在于词向量中
# 君子 : 不存在于词向量中
# 莫能 : 不存在于词向量中
# 之争 : 不存在于词向量中
# 天直 : 不存在于词向量中
# 心服口服 : 不存在于词向量中
# 蓝圈 : 不存在于词向量中
# 二哥 : 不存在于词向量中
# 好邦手 : 不存在于词向量中
# 读到 : 不存在于词向量中
# 能读 : 不存在于词向量中
# 小便 : 不存在于词向量中
# 小漠 : 不存在于词向量中
# 向前走 : 不存在于词向量中
# 慢则 : 不存在于词向量中
# 用得用 : 不存在于词向量中
# 额滴 : 不存在于词向量中
# 痛感 : 不存在于词向量中
# 棉子 : 不存在于词向量中
# 修成 : 不存在于词向量中
# 发说 : 不存在于词向量中
# 汤普森 : 不存在于词向量中
# 西装笔挺 : 不存在于词向量中
# 钮扣 : 不存在于词向量中
# 185 : 不存在于词向量中
# 寒是 : 不存在于词向量中
# 我木有 : 不存在于词向量中
# 一叠 : 不存在于词向量中
# 压一压 : 不存在于词向量中
# 没安卓 : 不存在于词向量中
# 重复性 : 不存在于词向量中
# 什要 : 不存在于词向量中
# 狭隘 : 不存在于词向量中
# VMALL : 不存在于词向量中
# 乱价 : 不存在于词向量中
# 变着法 : 不存在于词向量中
# 纹晃 : 不存在于词向量中
# 甜心 : 不存在于词向量中
# 点睛之笔 : 不存在于词向量中
# 同桌 : 不存在于词向量中
# 提供方便 : 不存在于词向量中
# 太朦 : 不存在于词向量中
# 一渣品 : 不存在于词向量中
# 连软壳 : 不存在于词向量中
# 系数 : 不存在于词向量中
# 一好 : 不存在于词向量中
# Novo2s : 不存在于词向量中
# 遗失 : 不存在于词向量中
# 买三免 : 不存在于词向量中
# 很合道 : 不存在于词向量中
# 收益 : 不存在于词向量中
# 亿能 : 不存在于词向量中
# MIIX5 : 不存在于词向量中
# MIIX510 : 不存在于词向量中
# 蜂拥而至 : 不存在于词向量中
# 48wh : 不存在于词向量中
# 倒像 : 不存在于词向量中
# 聚酯 : 不存在于词向量中
# 完熟 : 不存在于词向量中
# 很卡想 : 不存在于词向量中
# 贴张 : 不存在于词向量中
# 可事 : 不存在于词向量中
# 多人后 : 不存在于词向量中
# 评哈 : 不存在于词向量中
# 下版 : 不存在于词向量中
# 迦 : 不存在于词向量中
# 坏键 : 不存在于词向量中
# 天越 : 不存在于词向量中
# Y3 : 不存在于词向量中
# 按后 : 不存在于词向量中
# 一辆车 : 不存在于词向量中
# 开张 : 不存在于词向量中
# 业务量 : 不存在于词向量中
# 夜深人静 : 不存在于词向量中
# 错误想法 : 不存在于词向量中
# 食用 : 不存在于词向量中
# 总局 : 不存在于词向量中
# 吃定 : 不存在于词向量中
# 光明正大 : 不存在于词向量中
# 纸皮 : 不存在于词向量中
# 球蹭 : 不存在于词向量中
# 员特 : 不存在于词向量中
# 僈 : 不存在于词向量中
# 原坏件 : 不存在于词向量中
# 衰败 : 不存在于词向量中
# 元京卷 : 不存在于词向量中
# 入仓 : 不存在于词向量中
# 我放上 : 不存在于词向量中
# 那换 : 不存在于词向量中
# 默默无闻 : 不存在于词向量中
# 摩登 : 不存在于词向量中
# 直接了当 : 不存在于词向量中
# 捣鬼 : 不存在于词向量中
# 临睡前 : 不存在于词向量中
# 禳 : 不存在于词向量中
# 卖弄 : 不存在于词向量中
# 有空时 : 不存在于词向量中
# 起启 : 不存在于词向量中
# 货都备 : 不存在于词向量中
# 几百台 : 不存在于词向量中
# 政治 : 不存在于词向量中
# 狗腿子 : 不存在于词向量中
# 一览无余 : 不存在于词向量中
# 卖烂 : 不存在于词向量中
# 一撞 : 不存在于词向量中
# 我奶 : 不存在于词向量中
# 不比上 : 不存在于词向量中
# UG : 不存在于词向量中
# 孤独 : 不存在于词向量中
# 镭射 : 不存在于词向量中
# 不知所云 : 不存在于词向量中
# 语文 : 不存在于词向量中
# 石化 : 不存在于词向量中
# 倍京豆 : 不存在于词向量中
# 0.5% : 不存在于词向量中
# 少点 : 不存在于词向量中
# 光整 : 不存在于词向量中
# 骗得 : 不存在于词向量中
# 一世 : 不存在于词向量中
# 雷迪宾宝 : 不存在于词向量中
# 青春活力 : 不存在于词向量中
# 私人物品 : 不存在于词向量中
# 掌托 : 不存在于词向量中
# 存处 : 不存在于词向量中
# 一条龙 : 不存在于词向量中
# 情有独钟 : 不存在于词向量中
# 感在 : 不存在于词向量中
# 控件 : 不存在于词向量中
# 别着急 : 不存在于词向量中
# 本玩 : 不存在于词向量中
# 对口 : 不存在于词向量中
# 墨阳 : 不存在于词向量中
# 第九个 : 不存在于词向量中
# 维修期 : 不存在于词向量中
# tensor : 不存在于词向量中
# flow : 不存在于词向量中
# 狠狠心 : 不存在于词向量中
# 美关 : 不存在于词向量中
# 人造 : 不存在于词向量中
# 惊叹 : 不存在于词向量中
# 张全坏 : 不存在于词向量中
# ...
# 洗一水 : 不存在于词向量中
# 不太配 : 不存在于词向量中
# 下不去 : 不存在于词向量中
# 芭比 : 不存在于词向量中
# 脚可疼 : 不存在于词向量中
# 天电 : 不存在于词向量中
# 调下色 : 不存在于词向量中
# color : 不存在于词向量中
# 容纳 : 不存在于词向量中
# 本里算 : 不存在于词向量中
# 偏黑 : 不存在于词向量中
# 六七千 : 不存在于词向量中
# 小步 : 不存在于词向量中
# 太爽 : 不存在于词向量中
# 最青 : 不存在于词向量中
# 放腿 : 不存在于词向量中
# 漫天 : 不存在于词向量中
# 咕咕 : 不存在于词向量中
# 完刚 : 不存在于词向量中
# 说碎 : 不存在于词向量中
# 补买 : 不存在于词向量中
# 内带 : 不存在于词向量中
# 比裸 : 不存在于词向量中
# 多太多 : 不存在于词向量中
# 赏心悦目 : 不存在于词向量中
# 二活 : 不存在于词向量中
# 选小一码 : 不存在于词向量中
# F2LTJ48WHX9F : 不存在于词向量中
# 足球鞋 : 不存在于词向量中
# 四位 : 不存在于词向量中
# 磨得痛 : 不存在于词向量中
# 太惨 : 不存在于词向量中
# 少取 : 不存在于词向量中
# 下盖 : 不存在于词向量中
# 看笔 : 不存在于词向量中
# 机遇 : 不存在于词向量中
# 后防 : 不存在于词向量中
# 游个泳 : 不存在于词向量中
# 进房 : 不存在于词向量中
# crocs : 不存在于词向量中
# 碰一 : 不存在于词向量中
# 上皮 : 不存在于词向量中
# 亲戚家 : 不存在于词向量中
# 分好 : 不存在于词向量中
# .................... : 不存在于词向量中
# 机动车 : 不存在于词向量中
# 消灭 : 不存在于词向量中
# 妳 : 不存在于词向量中
# 媽的 : 不存在于词向量中
# 踏媽 : 不存在于词向量中
# 犀牛 : 不存在于词向量中
# 灰渍 : 不存在于词向量中
# 侧框 : 不存在于词向量中
# 感高配 : 不存在于词向量中
# I7CPU : 不存在于词向量中
# PGUP : 不存在于词向量中
# 20141202 : 不存在于词向量中
# oppoa59 : 不存在于词向量中
# 因旧 : 不存在于词向量中
# 红款 : 不存在于词向量中
# 突发奇想 : 不存在于词向量中
# 没闹 : 不存在于词向量中
# 蒙混过关 : 不存在于词向量中
# 受话 : 不存在于词向量中
# 针勒 : 不存在于词向量中
# 飞常 : 不存在于词向量中
# 未买全 : 不存在于词向量中
# 仔仔 : 不存在于词向量中
# 每间 : 不存在于词向量中
# 迷迷糊糊 : 不存在于词向量中
# 没是 : 不存在于词向量中
# 不凡 : 不存在于词向量中
# 哼哼唧唧 : 不存在于词向量中
# 好细 : 不存在于词向量中
# 能边 : 不存在于词向量中
# 只收 : 不存在于词向量中
# vpn : 不存在于词向量中
# 实拍 : 不存在于词向量中
# 829 : 不存在于词向量中
# 条链 : 不存在于词向量中
# 女装 : 不存在于词向量中
# 曹伟东 : 不存在于词向量中
# 未读 : 不存在于词向量中
# 巨额 : 不存在于词向量中
# 连触 : 不存在于词向量中
# 控都 : 不存在于词向量中
# 转嫁 : 不存在于词向量中
# 薄度 : 不存在于词向量中
# 最扎心 : 不存在于词向量中
# 法不像 : 不存在于词向量中
# 小写字母 : 不存在于词向量中
# APTX : 不存在于词向量中
# 下一场 : 不存在于词向量中
# 一下手 : 不存在于词向量中
# 700m : 不存在于词向量中
# 测机 : 不存在于词向量中
# 完回发 : 不存在于词向量中
# 大鞋 : 不存在于词向量中
# 更要 : 不存在于词向量中
# 光彩夺目 : 不存在于词向量中
# 自然美 : 不存在于词向量中
# 妆 : 不存在于词向量中
# 尴了尬 : 不存在于词向量中
# 原包 : 不存在于词向量中
# 赠点 : 不存在于词向量中
# 说键 : 不存在于词向量中
# 瘠薄 : 不存在于词向量中
# 以旧 : 不存在于词向量中
# 充新 : 不存在于词向量中
# 键会坏 : 不存在于词向量中
# 上些 : 不存在于词向量中
# 那鞋 : 不存在于词向量中
# 涂鸦 : 不存在于词向量中
# 参团 : 不存在于词向量中
# 丢速易 : 不存在于词向量中
# 基 : 不存在于词向量中
# 多试试 : 不存在于词向量中
# 虽少配 : 不存在于词向量中
# 百快 : 不存在于词向量中
# 纱 : 不存在于词向量中
# 兮兮 : 不存在于词向量中
# 激凸 : 不存在于词向量中
# 葫芦 : 不存在于词向量中
# 很怏 : 不存在于词向量中
# 高和极 : 不存在于词向量中
# 无二之选 : 不存在于词向量中
# 4.3 : 不存在于词向量中
# control : 不存在于词向量中
# sound : 不存在于词向量中
# blaster : 不存在于词向量中
# 一应 : 不存在于词向量中
# 具全 : 不存在于词向量中
# 热板 : 不存在于词向量中
# PM961 : 不存在于词向量中
# 售命 : 不存在于词向量中
# 330W : 不存在于词向量中
# 大功率 : 不存在于词向量中
# 发文件 : 不存在于词向量中
# 截下 : 不存在于词向量中
# 多遭 : 不存在于词向量中
# 大帅 : 不存在于词向量中
# 色彩感 : 不存在于词向量中
# 不比红米 : 不存在于词向量中
# 上买款 : 不存在于词向量中
# 用本 : 不存在于词向量中
# 记下 : 不存在于词向量中
# 锁机 : 不存在于词向量中
# 皇帝 : 不存在于词向量中
# 版不送 : 不存在于词向量中
# 只花 : 不存在于词向量中
# 急时 : 不存在于词向量中
# EXCELE : 不存在于词向量中
# 入侵 : 不存在于词向量中
# 未曾 : 不存在于词向量中
# 侵入 : 不存在于词向量中
# 遥远 : 不存在于词向量中
# 清真 : 不存在于词向量中
# 千八百 : 不存在于词向量中
# 换果 : 不存在于词向量中
# 日贵 : 不存在于词向量中
# 和斐讯体 : 不存在于词向量中
# 脂称 : 不存在于词向量中
# 582319973 : 不存在于词向量中
# 进千 : 不存在于词向量中
# 白金卡 : 不存在于词向量中
# 货架 : 不存在于词向量中
# 一半一半 : 不存在于词向量中
# 一卵样 : 不存在于词向量中
# 吃紧 : 不存在于词向量中
# 降成 : 不存在于词向量中
# 寄着 : 不存在于词向量中
# 少电 : 不存在于词向量中
# 供选择 : 不存在于词向量中
# 真硬 : 不存在于词向量中
# 百分之四十八 : 不存在于词向量中
# 彩屏 : 不存在于词向量中
# 现不说 : 不存在于词向量中
# 18.00 : 不存在于词向量中
# 20.00 : 不存在于词向量中
# 发京准 : 不存在于词向量中
# 待命 : 不存在于词向量中
# 烂声 : 不存在于词向量中
# gsync : 不存在于词向量中
# 鞋轻 : 不存在于词向量中
# 入内 : 不存在于词向量中
# 极窄 : 不存在于词向量中
# 不款 : 不存在于词向量中
# 得留 : 不存在于词向量中
# 电视屏幕 : 不存在于词向量中
# 烫脚 : 不存在于词向量中
# 开不亮 : 不存在于词向量中
# 店前 : 不存在于词向量中
# 网后 : 不存在于词向量中
# OppoA57 : 不存在于词向量中
# smar : 不存在于词向量中
# 亲力亲为 : 不存在于词向量中
# 这缝 : 不存在于词向量中
# 连过 : 不存在于词向量中
# 单大 : 不存在于词向量中
# 放远 : 不存在于词向量中
# 拍景 : 不存在于词向量中
# 早点儿 : 不存在于词向量中
# 知情 : 不存在于词向量中
# 潜台词 : 不存在于词向量中
# 王八 : 不存在于词向量中
# 口带 : 不存在于词向量中
# 实例 : 不存在于词向量中
# 旗 : 不存在于词向量中
# 一闪而过 : 不存在于词向量中
# 睡到 : 不存在于词向量中
# 狭得 : 不存在于词向量中
# 闽斯鸟 : 不存在于词向量中
# 二斤 : 不存在于词向量中
# 几克 : 不存在于词向量中
# 祱 : 不存在于词向量中
# 从零开始 : 不存在于词向量中
# 那轮 : 不存在于词向量中
# 偏淡 : 不存在于词向量中
# 大龄 : 不存在于词向量中
# 总偏 : 不存在于词向量中
# 手放 : 不存在于词向量中
# 手腕 : 不存在于词向量中
# 快熟了 : 不存在于词向量中
# 员太次 : 不存在于词向量中
# 裤片 : 不存在于词向量中
# 土黄色 : 不存在于词向量中
# 刮白 : 不存在于词向量中
# 深有 : 不存在于词向量中
# 200% : 不存在于词向量中
# 诱饵 : 不存在于词向量中
# 不复存在 : 不存在于词向量中
# 谷底 : 不存在于词向量中
# 留碎 : 不存在于词向量中
# 真买 : 不存在于词向量中
# 熄屏键 : 不存在于词向量中
# 熄 : 不存在于词向量中
# 有天 : 不存在于词向量中
# 前充 : 不存在于词向量中
# 关换 : 不存在于词向量中
# 稳滴 : 不存在于词向量中
# 安卓线 : 不存在于词向量中
# 接电 : 不存在于词向量中
# 淡雅 : 不存在于词向量中
# 试快 : 不存在于词向量中
# 勾到 : 不存在于词向量中
# 哪坏 : 不存在于词向量中
# 精日罗吹 : 不存在于词向量中
# 贵人 : 不存在于词向量中
# 满快 : 不存在于词向量中
# 尴不 : 不存在于词向量中
# 多有 : 不存在于词向量中
# 主任 : 不存在于词向量中
# 裂音 : 不存在于词向量中
# 亚克力 : 不存在于词向量中
# 硬盘驱动器 : 不存在于词向量中
# 加密 : 不存在于词向量中
# 灯亮了 : 不存在于词向量中
# 足感 : 不存在于词向量中
# 价线 : 不存在于词向量中
# 无可否认 : 不存在于词向量中
# 天之久 : 不存在于词向量中
# 国家邮政局 : 不存在于词向量中
# 送贷 : 不存在于词向量中
# 对联 : 不存在于词向量中
# 狭窄 : 不存在于词向量中
# 心才 : 不存在于词向量中
# 封页 : 不存在于词向量中
# 大陆同胞 : 不存在于词向量中
# 同等对待 : 不存在于词向量中
# 红点 : 不存在于词向量中
# 收美团 : 不存在于词向量中
# 发收 : 不存在于词向量中
# 骚不骚 : 不存在于词向量中
# 折买碎 : 不存在于词向量中
# 还管 : 不存在于词向量中
# 盲哥 : 不存在于词向量中
# 开满效 : 不存在于词向量中
# 杂种 : 不存在于词向量中
# 力太多 : 不存在于词向量中
# 9.17 : 不存在于词向量中
# 11.8 : 不存在于词向量中
# 049 : 不存在于词向量中
# 050 : 不存在于词向量中
# boost : 不存在于词向量中
# 保温杯 : 不存在于词向量中
# 九年 : 不存在于词向量中
# 度上 : 不存在于词向量中
# 肯退 : 不存在于词向量中
# 太上 : 不存在于词向量中
# 购吧 : 不存在于词向量中
# 娜娜 : 不存在于词向量中
# 以卖 : 不存在于词向量中
# 客房 : 不存在于词向量中
# 低仿 : 不存在于词向量中
# 种种原因 : 不存在于词向量中
# 磨脚磨 : 不存在于词向量中
# 脚磨脚 : 不存在于词向量中
# 分送 : 不存在于词向量中
# 瘦瘦高高 : 不存在于词向量中
# 样纸 : 不存在于词向量中
# 是动 : 不存在于词向量中
# 血泡 : 不存在于词向量中
# 不耐划 : 不存在于词向量中
# hair : 不存在于词向量中
# 调休 : 不存在于词向量中
# 输入输出 : 不存在于词向量中
# 中微信 : 不存在于词向量中
# 洋洋得意 : 不存在于词向量中
# 被窝 : 不存在于词向量中
# 师范生 : 不存在于词向量中
# 沉想 : 不存在于词向量中
# 55.9 : 不存在于词向量中
# 多档 : 不存在于词向量中
# 钱太多 : 不存在于词向量中
# 买哈 : 不存在于词向量中
# 推拖 : 不存在于词向量中
# 预料之中 : 不存在于词向量中
# 八买 : 不存在于词向量中
# 脚低 : 不存在于词向量中
# 穴位 : 不存在于词向量中
# 外衣 : 不存在于词向量中
# 拮据 : 不存在于词向量中
# 标都 : 不存在于词向量中
# 忘压 : 不存在于词向量中
# 边儿 : 不存在于词向量中
# 安新 : 不存在于词向量中
# 南有 : 不存在于词向量中
# 北有 : 不存在于词向量中
# 聚集地 : 不存在于词向量中
# 不堪回首 : 不存在于词向量中
# 插回去 : 不存在于词向量中
# 芝士 : 不存在于词向量中
# 终归是 : 不存在于词向量中
# 内不退 : 不存在于词向量中
# 中给力 : 不存在于词向量中
# 128pro : 不存在于词向量中
# 用白 : 不存在于词向量中
# 中多 : 不存在于词向量中
# 机红米 : 不存在于词向量中
# X1Carbon : 不存在于词向量中
# MicroSD : 不存在于词向量中
# 没骁龙 : 不存在于词向量中
# 员得 : 不存在于词向量中
# Tc : 不存在于词向量中
# 无旗航 : 不存在于词向量中
# 蓬隙 : 不存在于词向量中
# Note56 : 不存在于词向量中
# 暂放 : 不存在于词向量中
# 内部资料 : 不存在于词向量中
# 高度重视 : 不存在于词向量中
# 认可度 : 不存在于词向量中
# 三十七八 : 不存在于词向量中
# 脚能 : 不存在于词向量中
# 机寄 : 不存在于词向量中
# 吞货 : 不存在于词向量中
# 这特步 : 不存在于词向量中
# 高亲们 : 不存在于词向量中
# 适于 : 不存在于词向量中
# 出卡槽 : 不存在于词向量中
# 最弱 : 不存在于词向量中
# M430 : 不存在于词向量中
# 5528b : 不存在于词向量中
# 3467 : 不存在于词向量中
# 我哥试 : 不存在于词向量中
# 少放 : 不存在于词向量中
# 补星 : 不存在于词向量中
# 资金不足 : 不存在于词向量中
# 重配 : 不存在于词向量中
# 敬而远之 : 不存在于词向量中
# 信懶 : 不存在于词向量中
# 扱 : 不存在于词向量中
# 比慢 : 不存在于词向量中
# 近年 : 不存在于词向量中
# 换得 : 不存在于词向量中
# 360n5lite : 不存在于词向量中
# 12.11 : 不存在于词向量中
# 哪件 : 不存在于词向量中
# hao : 不存在于词向量中
# phone6p : 不存在于词向量中
# gc : 不存在于词向量中
# 栏目 : 不存在于词向量中
# 屏为 : 不存在于词向量中
# 换山星 : 不存在于词向量中
# 米其林 : 不存在于词向量中
# 斌 : 不存在于词向量中
# 包真 : 不存在于词向量中
# 工错 : 不存在于词向量中
# 加补 : 不存在于词向量中
# 轻不说 : 不存在于词向量中
# 上假 : 不存在于词向量中
# 臭胶 : 不存在于词向量中
# 哎差 : 不存在于词向量中
# 东四 : 不存在于词向量中
# 屏侧 : 不存在于词向量中
# 实验品 : 不存在于词向量中
# 充不讲 : 不存在于词向量中
# X260 : 不存在于词向量中
# 落班 : 不存在于词向量中
# 好此 : 不存在于词向量中
# 报复性 : 不存在于词向量中
# 园园 : 不存在于词向量中
# 那批 : 不存在于词向量中
# 有红漆 : 不存在于词向量中
# 戳破 : 不存在于词向量中
# wfif : 不存在于词向量中
# 未标明 : 不存在于词向量中
# 退一步 : 不存在于词向量中
# 帮加 : 不存在于词向量中
# 坑太多 : 不存在于词向量中
# 摆托 : 不存在于词向量中
# 风光 : 不存在于词向量中
# 查收 : 不存在于词向量中
# 盒套 : 不存在于词向量中
# AL : 不存在于词向量中
# 刷到 : 不存在于词向量中
# 不买安卓 : 不存在于词向量中
# 充棉 : 不存在于词向量中
# 小漆点 : 不存在于词向量中
# 憋曲 : 不存在于词向量中
# 五百万 : 不存在于词向量中
# 纹特 : 不存在于词向量中
# 催货后 : 不存在于词向量中
# 县级 : 不存在于词向量中
# 卡得牙 : 不存在于词向量中
# 连高仿 : 不存在于词向量中
# 哪双 : 不存在于词向量中
# 特玛醉 : 不存在于词向量中
# 540 : 不存在于词向量中
# 砍价 : 不存在于词向量中
# 2183 : 不存在于词向量中
# Ni : 不存在于词向量中
# 玛一星 : 不存在于词向量中
# 寄费 : 不存在于词向量中
# 海行 : 不存在于词向量中
# 和华 : 不存在于词向量中
# 左角 : 不存在于词向量中
# Lenovo : 不存在于词向量中
# 天逸 : 不存在于词向量中
# 510S : 不存在于词向量中
# 4G1T : 不存在于词向量中
# 摩电 : 不存在于词向量中
# 硬挤 : 不存在于词向量中
# 脚碎 : 不存在于词向量中
# 众人 : 不存在于词向量中
# 多买台 : 不存在于词向量中
# 五开 : 不存在于词向量中
# 打怪 : 不存在于词向量中
# 店太坑 : 不存在于词向量中
# 小灰斑 : 不存在于词向量中
# XP13 : 不存在于词向量中
# 垫胶 : 不存在于词向量中
# 鬼来 : 不存在于词向量中
# 弄死 : 不存在于词向量中
# 长到 : 不存在于词向量中
# 数有 : 不存在于词向量中
# Z11min : 不存在于词向量中
# Z17m : 不存在于词向量中
# 降时 : 不存在于词向量中
# 贱骨头 : 不存在于词向量中
# 刚够 : 不存在于词向量中
# batch : 不存在于词向量中
# 8G128 : 不存在于词向量中
# 麻将 : 不存在于词向量中
# 追查 : 不存在于词向量中
# 习 : 不存在于词向量中
# 敦敦 : 不存在于词向量中
# 我联 : 不存在于词向量中
# 发小码 : 不存在于词向量中
# 先赞下 : 不存在于词向量中
# 谈下 : 不存在于词向量中
# 滑着走 : 不存在于词向量中
# 组个 : 不存在于词向量中
# 开难 : 不存在于词向量中
# 希拉 : 不存在于词向量中
# 莱斯 : 不存在于词向量中
# 领物 : 不存在于词向量中
# 棱边 : 不存在于词向量中
# 图牌 : 不存在于词向量中
# 破口大骂 : 不存在于词向量中
# TOUCH : 不存在于词向量中
# 直板 : 不存在于词向量中
# 还給 : 不存在于词向量中
# 正当防卫 : 不存在于词向量中
# 没报 : 不存在于词向量中
# 老铁全 : 不存在于词向量中
# Boss : 不存在于词向量中
# 十软 : 不存在于词向量中
# 妹币 : 不存在于词向量中
# 不修要 : 不存在于词向量中
# 管一管 : 不存在于词向量中
# 5.93 : 不存在于词向量中
# 仲有 : 不存在于词向量中
# 打得少 : 不存在于词向量中
# 勾坏 : 不存在于词向量中
# Z5p : 不存在于词向量中
# XZ2 : 不存在于词向量中
# 上门去 : 不存在于词向量中
# 水盆 : 不存在于词向量中
# miu : 不存在于词向量中
# 寄达 : 不存在于词向量中
# 先扣 : 不存在于词向量中
# 变重 : 不存在于词向量中
# 货优 : 不存在于词向量中
# 罗总 : 不存在于词向量中
# 课程 : 不存在于词向量中
# 差有 : 不存在于词向量中
# 雷哥 : 不存在于词向量中
# 扩存 : 不存在于词向量中
# 老姿 : 不存在于词向量中
# 有卡停 : 不存在于词向量中
# 零元 : 不存在于词向量中
# 一岁 : 不存在于词向量中
# 这经 : 不存在于词向量中
# 灯能 : 不存在于词向量中
# 决赛 : 不存在于词向量中
# 通处 : 不存在于词向量中
# 微缝 : 不存在于词向量中
# 听通 : 不存在于词向量中
# 衬衫面料 : 不存在于词向量中
# 这机机 : 不存在于词向量中
# 戍 : 不存在于词向量中
# 另个 : 不存在于词向量中
# 8599 : 不存在于词向量中
# 惠普公司 : 不存在于词向量中
# 悔青 : 不存在于词向量中
# 誉品 : 不存在于词向量中
# YEPEN : 不存在于词向量中
# YP99 : 不存在于词向量中
# 电霸 : 不存在于词向量中
# 时全 : 不存在于词向量中
# 碰不出 : 不存在于词向量中
# 浅浅的 : 不存在于词向量中
# 摸下 : 不存在于词向量中
# 驻场 : 不存在于词向量中
# 要太大 : 不存在于词向量中
# 下后 : 不存在于词向量中
# 摄大 : 不存在于词向量中
# 3d4 : 不存在于词向量中
# 68KG : 不存在于词向量中
# wma : 不存在于词向量中
# 甬 : 不存在于词向量中
# 拿腔 : 不存在于词向量中
# 调装 : 不存在于词向量中
# CTO : 不存在于词向量中
# 医药 : 不存在于词向量中
# 折影 : 不存在于词向量中
# ubuntu16.04 : 不存在于词向量中
# grub : 不存在于词向量中
# acpi : 不存在于词向量中
# 啸叫 : 不存在于词向量中
# 插到 : 不存在于词向量中
# 十二度 : 不存在于词向量中
# 个步 : 不存在于词向量中
# 显老 : 不存在于词向量中
# 256666 : 不存在于词向量中
# 战不动 : 不存在于词向量中
# 航空母舰 : 不存在于词向量中
# 说重 : 不存在于词向量中
# 背久 : 不存在于词向量中
# 4cm : 不存在于词向量中
# 滑丝 : 不存在于词向量中
# 血轮 : 不存在于词向量中
# 我周 : 不存在于词向量中
# 天刚 : 不存在于词向量中
# 机拿 : 不存在于词向量中
# 批爆 : 不存在于词向量中
# 两哈 : 不存在于词向量中
# 1138 : 不存在于词向量中
# 党真 : 不存在于词向量中
# 虚高割 : 不存在于词向量中
# 韭菜 : 不存在于词向量中
# 亲民价 : 不存在于词向量中
# 挨宰 : 不存在于词向量中
# 本书 : 不存在于词向量中
# 老怕 : 不存在于词向量中
# 一千二 : 不存在于词向量中
# 评优 : 不存在于词向量中
# 办公区 : 不存在于词向量中
# 4400 : 不存在于词向量中
# 风噪 : 不存在于词向量中
# MEI : 不存在于词向量中
# PCI : 不存在于词向量中
# 组态 : 不存在于词向量中
# 完包 : 不存在于词向量中
# 颜有型 : 不存在于词向量中
# 老得 : 不存在于词向量中
# 多元智能 : 不存在于词向量中
# 跻身 : 不存在于词向量中
# 何德何能 : 不存在于词向量中
# 牛逼卖 : 不存在于词向量中
# 点正 : 不存在于词向量中
# 第二手 : 不存在于词向量中
# 深坑 : 不存在于词向量中
# 超有型 : 不存在于词向量中
# 垃鞋 : 不存在于词向量中
# 金融服务 : 不存在于词向量中
# 怪会坏 : 不存在于词向量中
# officer : 不存在于词向量中
# 供方 : 不存在于词向量中
# 需方 : 不存在于词向量中
# 验收单 : 不存在于词向量中
# 盖章 : 不存在于词向量中
# 致使 : 不存在于词向量中
# 账务 : 不存在于词向量中
# ∶ : 不存在于词向量中
# 液会 : 不存在于词向量中
# 长点会 : 不存在于词向量中
# 装点 : 不存在于词向量中
# 磕花 : 不存在于词向量中
# 十几斤 : 不存在于词向量中
# 金好 : 不存在于词向量中
# 累赘 : 不存在于词向量中
# 虫子 : 不存在于词向量中
# FD : 不存在于词向量中
# 彩色图片 : 不存在于词向量中
# 正百搭款 : 不存在于词向量中
# 饼铛 : 不存在于词向量中
# uarr : 不存在于词向量中
# 图满格 : 不存在于词向量中
# 半颜值 : 不存在于词向量中
# 出线 : 不存在于词向量中
# 不卡哟 : 不存在于词向量中
# 失真度 : 不存在于词向量中
# 按健坏 : 不存在于词向量中
# 心赛 : 不存在于词向量中
# 载体 : 不存在于词向量中
# 出趟 : 不存在于词向量中
# z370 : 不存在于词向量中
# n956 : 不存在于词向量中
# p751 : 不存在于词向量中
# 有快 : 不存在于词向量中
# 拆板 : 不存在于词向量中
# zx7cp5s2 : 不存在于词向量中
# 7088 : 不存在于词向量中
# 喝点 : 不存在于词向量中
# 几到 : 不存在于词向量中
# 哪放 : 不存在于词向量中
# 哪法 : 不存在于词向量中
# 姬娜 : 不存在于词向量中
# 太笨 : 不存在于词向量中
# 处掉 : 不存在于词向量中
# 臂套 : 不存在于词向量中
# 凑数 : 不存在于词向量中
# 96.2 : 不存在于词向量中
# FIG : 不存在于词向量中
# 技术细节 : 不存在于词向量中
# 竞不 : 不存在于词向量中
# 溜秋 : 不存在于词向量中
# 會 : 不存在于词向量中
# 然後想 : 不存在于词向量中
# 雞 : 不存在于词向量中
# 壓力 : 不存在于词向量中
# 接電不開 : 不存在于词向量中
# 頂配 : 不存在于词向量中
# OK2 : 不存在于词向量中
# 風扇 : 不存在于词向量中
# 明顯 : 不存在于词向量中
# 可見 : 不存在于词向量中
# 開小風 : 不存在于词向量中
# 大聲 : 不存在于词向量中
# 半袋 : 不存在于词向量中
# 發現 : 不存在于词向量中
# 補充 : 不存在于词向量中
# 能卡退 : 不存在于词向量中
# 电灯 : 不存在于词向量中
# 误开 : 不存在于词向量中
# 绝世 : 不存在于词向量中
# 胶漆 : 不存在于词向量中
# 庚庚 : 不存在于词向量中
# 釜 : 不存在于词向量中
# 擦除 : 不存在于词向量中
# 喜忧参半 : 不存在于词向量中
# 天至 : 不存在于词向量中
# 才测 : 不存在于词向量中
# 差鲁 : 不存在于词向量中
# 衣穿 : 不存在于词向量中
# 5.28 : 不存在于词向量中
# 棒赞 : 不存在于词向量中
# 我磨 : 不存在于词向量中
# 不玩买 : 不存在于词向量中
# 50T : 不存在于词向量中
# 又哭又闹 : 不存在于词向量中
# 天台 : 不存在于词向量中
# 调研组 : 不存在于词向量中
# 市场调研 : 不存在于词向量中
# 想害 : 不存在于词向量中
# 不及格 : 不存在于词向量中
# get : 不存在于词向量中
# 641299 : 不存在于词向量中
# 一惯 : 不存在于词向量中
# 车站 : 不存在于词向量中
# 人为失误 : 不存在于词向量中
# 倒立 : 不存在于词向量中
# 看公 : 不存在于词向量中
# 争相 : 不存在于词向量中
# 撑起 : 不存在于词向量中
# 能取 : 不存在于词向量中
# 刚有件 : 不存在于词向量中
# 特显 : 不存在于词向量中
# 配过 : 不存在于词向量中
# 孔掉 : 不存在于词向量中
# X201 : 不存在于词向量中
# 就弃 : 不存在于词向量中
# 夹住 : 不存在于词向量中
# 短发 : 不存在于词向量中
# 天半才 : 不存在于词向量中
# 就事论事 : 不存在于词向量中
# 受价保 : 不存在于词向量中
# 这令 : 不存在于词向量中
# 机谁信 : 不存在于词向量中
# 人退 : 不存在于词向量中
# 易胖 : 不存在于词向量中
# 体质 : 不存在于词向量中
# 调理 : 不存在于词向量中
# 路子 : 不存在于词向量中
# 刮点 : 不存在于词向量中
# 商业道德 : 不存在于词向量中
# 物是 : 不存在于词向量中
# 信息安全 : 不存在于词向量中
# 4M : 不存在于词向量中
# 太多话 : 不存在于词向量中
# 温文 : 不存在于词向量中
# 如玉 : 不存在于词向量中
# 没存 : 不存在于词向量中
# 98G : 不存在于词向量中
# 3k5 : 不存在于词向量中
# 3k6 : 不存在于词向量中
# 3k7 : 不存在于词向量中
# bai : 不存在于词向量中
# 大雷 : 不存在于词向量中
# 有口难辩 : 不存在于词向量中
# 12.25 : 不存在于词向量中
# 按反 : 不存在于词向量中
# 回建 : 不存在于词向量中
# 数码城 : 不存在于词向量中
# 常清 : 不存在于词向量中
# 还怨 : 不存在于词向量中
# 数个 : 不存在于词向量中
# 评给 : 不存在于词向量中
# 发留言 : 不存在于词向量中
# 有减 : 不存在于词向量中
# 综述 : 不存在于词向量中
# 一不样 : 不存在于词向量中
# 巴特 : 不存在于词向量中
# 拍购 : 不存在于词向量中
# 拉车 : 不存在于词向量中
# 天雨 : 不存在于词向量中
# 332772 : 不存在于词向量中
# 有话要说 : 不存在于词向量中
# 我耗 : 不存在于词向量中
# 很耐操 : 不存在于词向量中
# 地选下 : 不存在于词向量中
# 莽撞 : 不存在于词向量中
# 自罚 : 不存在于词向量中
# 一杯 : 不存在于词向量中
# 小美是 : 不存在于词向量中
# 做持 : 不存在于词向量中
# 没供 : 不存在于词向量中
# 刚接 : 不存在于词向量中
# 螺母 : 不存在于词向量中
# 足球队 : 不存在于词向量中
# fake : 不存在于词向量中
# 差当 : 不存在于词向量中
# 摔死 : 不存在于词向量中
# 热脚 : 不存在于词向量中
# 内退 : 不存在于词向量中
# 黑旗 : 不存在于词向量中
# 妈卡 : 不存在于词向量中
# 灵时 : 不存在于词向量中
# 乱扣 : 不存在于词向量中
# 下旬 : 不存在于词向量中
# 考滤 : 不存在于词向量中
# 不饱和 : 不存在于词向量中
# 电脑产品 : 不存在于词向量中
# 765 : 不存在于词向量中
# 大宗 : 不存在于词向量中
# 有莎莎 : 不存在于词向量中
# 想换款 : 不存在于词向量中
# 退认 : 不存在于词向量中
# 春装 : 不存在于词向量中
# 重录 : 不存在于词向量中
# 天找 : 不存在于词向量中
# 能靠点 : 不存在于词向量中
# 十打 : 不存在于词向量中
# 注入 : 不存在于词向量中
# GTX : 不存在于词向量中
# 950M : 不存在于词向量中
# 音响系统 : 不存在于词向量中
# 代酷 : 不存在于词向量中
# 节制 : 不存在于词向量中
# 特质 : 不存在于词向量中
# Trackpoint : 不存在于词向量中
# Think : 不存在于词向量中
# Cool : 不存在于词向量中
# APS : 不存在于词向量中
# 范的 : 不存在于词向量中
# 搞乃查 : 不存在于词向量中
# 个条 : 不存在于词向量中
# Z2 : 不存在于词向量中
# 线少 : 不存在于词向量中
# 包没送 : 不存在于词向量中
# 元旦节 : 不存在于词向量中
# 现代化 : 不存在于词向量中
# 爽购 : 不存在于词向量中
# 内控 : 不存在于词向量中
# 选慢 : 不存在于词向量中
# 束 : 不存在于词向量中
# 仍受 : 不存在于词向量中
# 无济于事 : 不存在于词向量中
# 第一行 : 不存在于词向量中
# 我招 : 不存在于词向量中
# 航旅 : 不存在于词向量中
# 纵横 : 不存在于词向量中
# 缩短 : 不存在于词向量中
# 本文 : 不存在于词向量中
# 6737T : 不存在于词向量中
# 3020mAh : 不存在于词向量中
# 几项 : 不存在于词向量中
# 不难看出 : 不存在于词向量中
# .% : 不存在于词向量中
# 牙菌斑 : 不存在于词向量中
# 刷牙 : 不存在于词向量中
# 多方位 : 不存在于词向量中
# 小不伤 : 不存在于词向量中
# 牙龈 : 不存在于词向量中
# 赖账 : 不存在于词向量中
# 胆大妄为 : 不存在于词向量中
# 1.18 : 不存在于词向量中
# 下解 : 不存在于词向量中
# nt10 : 不存在于词向量中
# 谈好 : 不存在于词向量中
# 审查 : 不存在于词向量中
# 三不管 : 不存在于词向量中
# 1000000 : 不存在于词向量中
# 连查 : 不存在于词向量中
# 有脏 : 不存在于词向量中
# 新宠 : 不存在于词向量中
# G4560 : 不存在于词向量中
# 非国行 : 不存在于词向量中
# 秀米 : 不存在于词向量中
# 卡出翔 : 不存在于词向量中
# 轰炸机 : 不存在于词向量中
# 飘亮 : 不存在于词向量中
# 全说 : 不存在于词向量中
# 479 : 不存在于词向量中
# 频能 : 不存在于词向量中
# 如斯 : 不存在于词向量中
# 机房 : 不存在于词向量中
# 杰作 : 不存在于词向量中
# 充值卡 : 不存在于词向量中
# 好花骚 : 不存在于词向量中
# 货行 : 不存在于词向量中
# 太逗 : 不存在于词向量中
# 店干到 : 不存在于词向量中
# ASICS : 不存在于词向量中
# 绚卡 : 不存在于词向量中
# 点帮 : 不存在于词向量中
# 想想也是 : 不存在于词向量中
# 长配 : 不存在于词向量中
# 推选 : 不存在于词向量中
# 皱褶 : 不存在于词向量中
# 裤衩 : 不存在于词向量中
# 处太 : 不存在于词向量中
# 感器 : 不存在于词向量中
# 几人 : 不存在于词向量中
# 鬼马 : 不存在于词向量中
# 屏慢 : 不存在于词向量中
# 无得 : 不存在于词向量中
# 最头 : 不存在于词向量中
# 阻滞 : 不存在于词向量中
# 得拔 : 不存在于词向量中
# windiws10 : 不存在于词向量中
# sp : 不存在于词向量中
# 差掉 : 不存在于词向量中
# 好心人 : 不存在于词向量中
# 暗多 : 不存在于词向量中
# 重要文件 : 不存在于词向量中
# 刚过去 : 不存在于词向量中
# 侧部 : 不存在于词向量中
# 脸疼 : 不存在于词向量中
# 乐涩 : 不存在于词向量中
# 垃级 : 不存在于词向量中
# 卡开 : 不存在于词向量中
# 深表 : 不存在于词向量中
# 望思 : 不存在于词向量中
# 返利 : 不存在于词向量中
# 2.1% : 不存在于词向量中
# 0.35% : 不存在于词向量中
# 写返 : 不存在于词向量中
# 对头 : 不存在于词向量中
# 黑机 : 不存在于词向量中
# 软穿 : 不存在于词向量中
# 别学 : 不存在于词向量中
# 两三倍 : 不存在于词向量中
# 上整 : 不存在于词向量中
# 头碎 : 不存在于词向量中
# 30FPS : 不存在于词向量中
# 白开 : 不存在于词向量中
# 券白 : 不存在于词向量中
# 分八 : 不存在于词向量中
# 调派 : 不存在于词向量中
# 应酬 : 不存在于词向量中
# 贫 : 不存在于词向量中
# 张车 : 不存在于词向量中
# 登山鞋 : 不存在于词向量中
# 梅红 : 不存在于词向量中
# W61303512 : 不存在于词向量中
# 曹小军 : 不存在于词向量中
# 284 : 不存在于词向量中
# 深山老林 : 不存在于词向量中
# 如新 : 不存在于词向量中
# 脑阔 : 不存在于词向量中
# 精神分裂 : 不存在于词向量中
# 盗后 : 不存在于词向量中
# 小而薄 : 不存在于词向量中
# 山案机 : 不存在于词向量中
# 调高 : 不存在于词向量中
# 两度 : 不存在于词向量中
# 赠二膜 : 不存在于词向量中
# 整款 : 不存在于词向量中
# 辣圾 : 不存在于词向量中
# 能少开 : 不存在于词向量中
# 柔美 : 不存在于词向量中
# 瞧瞧 : 不存在于词向量中
# 强差 : 不存在于词向量中
# 修路 : 不存在于词向量中
# nba2k14 : 不存在于词向量中
# 还理 : 不存在于词向量中
# EXCEL : 不存在于词向量中
# 走来走去 : 不存在于词向量中
# 望后 : 不存在于词向量中
# zhazha : 不存在于词向量中
# ROG : 不存在于词向量中
# 死贵且 : 不存在于词向量中
# 灯厂 : 不存在于词向量中
# AW : 不存在于词向量中
# 夏天无 : 不存在于词向量中
# 踏入社会 : 不存在于词向量中
# 区政府 : 不存在于词向量中
# 钢带 : 不存在于词向量中
# 旗航 : 不存在于词向量中
# 系统维护 : 不存在于词向量中
# 无年 : 不存在于词向量中
# 次开 : 不存在于词向量中
# 登门 : 不存在于词向量中
# 响起 : 不存在于词向量中
# 冤不冤 : 不存在于词向量中
# 还卡到 : 不存在于词向量中
# 匠心独运 : 不存在于词向量中
# 前掌 : 不存在于词向量中
# 搞裂 : 不存在于词向量中
# 物留 : 不存在于词向量中
# 车厘子 : 不存在于词向量中
# 断绝 : 不存在于词向量中
# 提额促 : 不存在于词向量中
# 2048 : 不存在于词向量中
# SQX4650 : 不存在于词向量中
# 740N : 不存在于词向量中
# 4GDDR4 : 不存在于词向量中
# 助 : 不存在于词向量中
# 中像 : 不存在于词向量中
# 别买别 : 不存在于词向量中
# 三千年 : 不存在于词向量中
# 相思 : 不存在于词向量中
# 红颜色 : 不存在于词向量中
# 1219 : 不存在于词向量中
# 一记 : 不存在于词向量中
# 匡 : 不存在于词向量中
# 环掉 : 不存在于词向量中
# 2gb : 不存在于词向量中
# 我肯 : 不存在于词向量中
# 不动会 : 不存在于词向量中
# 期从 : 不存在于词向量中
# 裤链 : 不存在于词向量中
# 爆线 : 不存在于词向量中
# 9759 : 不存在于词向量中
# 京豆够 : 不存在于词向量中
# 9700 : 不存在于词向量中
# 各用 : 不存在于词向量中
# 整包 : 不存在于词向量中
# 餐巾纸 : 不存在于词向量中
# 三四家 : 不存在于词向量中
# 890 : 不存在于词向量中
# 背到 : 不存在于词向量中
# 转场 : 不存在于词向量中
# 买充 : 不存在于词向量中
# 卡双待 : 不存在于词向量中
# 急待 : 不存在于词向量中
# 刚提 : 不存在于词向量中
# 二十九 : 不存在于词向量中
# 戏剧性 : 不存在于词向量中
# 一幕 : 不存在于词向量中
# 夏 : 不存在于词向量中
# 不号 : 不存在于词向量中
# 要整 : 不存在于词向量中
# 离死 : 不存在于词向量中
# 装聋卖傻 : 不存在于词向量中
# 掩耳盗铃 : 不存在于词向量中
# 挥霍 : 不存在于词向量中
# 很断 : 不存在于词向量中
# 才免 : 不存在于词向量中
# 两元 : 不存在于词向量中
# 来刷 : 不存在于词向量中
# 率多高 : 不存在于词向量中
# 换算 : 不存在于词向量中
# 盒大 : 不存在于词向量中
# 鸟叫 : 不存在于词向量中
# 神店 : 不存在于词向量中
# 玩点 : 不存在于词向量中
# 少卡顿 : 不存在于词向量中
# 能关 : 不存在于词向量中
# 装谷歌 : 不存在于词向量中
# 这成 : 不存在于词向量中
# 赞哟 : 不存在于词向量中
# 我蠢 : 不存在于词向量中
# 信得 : 不存在于词向量中
# lolfps : 不存在于词向量中
# 200k : 不存在于词向量中
# mete : 不存在于词向量中
# 系类 : 不存在于词向量中
# 防侧 : 不存在于词向量中
# 杜 : 不存在于词向量中
# 天热死 : 不存在于词向量中
# 长眼 : 不存在于词向量中
# 主营 : 不存在于词向量中
# 买瓶 : 不存在于词向量中
# 256SSD : 不存在于词向量中
# 问发个 : 不存在于词向量中
# 土亢 : 不存在于词向量中
# superme : 不存在于词向量中
# 卢克团 : 不存在于词向量中
# 218M : 不存在于词向量中
# 暴光 : 不存在于词向量中
# 门后 : 不存在于词向量中
# 配称 : 不存在于词向量中
# 科幻片 : 不存在于词向量中
# 比爽 : 不存在于词向量中
# 请些 : 不存在于词向量中
# Android8 : 不存在于词向量中
# 感全 : 不存在于词向量中
# 卡频 : 不存在于词向量中
# 敢接 : 不存在于词向量中
# 说怕 : 不存在于词向量中
# 市场占有率 : 不存在于词向量中
# 空包 : 不存在于词向量中
# 代发 : 不存在于词向量中
# 丰都 : 不存在于词向量中
# 重发 : 不存在于词向量中
# 酷毙 : 不存在于词向量中
# 复评 : 不存在于词向量中
# 不烧 : 不存在于词向量中
# 算命 : 不存在于词向量中
# 袍 : 不存在于词向量中
# 指围 : 不存在于词向量中
# 叽里呱啦 : 不存在于词向量中
# 闻所未闻 : 不存在于词向量中
# sq : 不存在于词向量中
# 一有准 : 不存在于词向量中
# 妈心 : 不存在于词向量中
# 白血病 : 不存在于词向量中
# 包刚 : 不存在于词向量中
# 大清 : 不存在于词向量中
# 取走会 : 不存在于词向量中
# 不宰 : 不存在于词向量中
# 气场 : 不存在于词向量中
# 常态 : 不存在于词向量中
# 26W : 不存在于词向量中
# 本货 : 不存在于词向量中
# 次款 : 不存在于词向量中
# 136000 : 不存在于词向量中
# 台玩微 : 不存在于词向量中
# 信会 : 不存在于词向量中
# 改还行 : 不存在于词向量中
# 团战声 : 不存在于词向量中
# 筒子 : 不存在于词向量中
# 递个 : 不存在于词向量中
# 拆换 : 不存在于词向量中
# 鞋好 : 不存在于词向量中
# 必经 : 不存在于词向量中
# 开业 : 不存在于词向量中
# 午夜 : 不存在于词向量中
# 神乎其技 : 不存在于词向量中
# 入生 : 不存在于词向量中
# 拉色 : 不存在于词向量中
# 抵不上 : 不存在于词向量中
# OP11 : 不存在于词向量中
# 次不次 : 不存在于词向量中
# 妄下 : 不存在于词向量中

# %%
print("train data shape: {}".format(data.trainReviews.shape))
print("train label shape: {}".format(data.trainLabels.shape))
print("eval data shape: {}".format(data.evalReviews.shape))
# Out:
# train data shape: (80846, 200)
# train label shape: (80846, 2)
# eval data shape: (20212, 200)

# %% [markdown]
# # 定义网络结构

# %%
def train_lstm(n_symbols,embedding_weights,config):
    
    model =Sequential([
        Embedding(input_dim=n_symbols, output_dim=config.model.embeddingSize,
                        weights=[embedding_weights],
                        input_length=config.sequenceLength),
        
    #LSTM层
    LSTM(50,activation='tanh', dropout=0.5, recurrent_dropout=0.5),
    Dropout(config.model.dropoutKeepProb),
    Dense(2, activation='sigmoid',kernel_regularizer=regularizers.l2(config.model.l2RegLambda))])
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

    return model
    
    
    
wordEmbedding = data.wordEmbedding
n_symbols=data.n_symbols
model = train_lstm(n_symbols,wordEmbedding,config)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 200, 110)          2754730
# _________________________________________________________________
# unified_lstm_3 (UnifiedLSTM) (None, 50)                32200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 2,787,032
# Trainable params: 2,787,032
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 训练模型

# %%
x_train = data.trainReviews
y_train = data.trainLabels
x_eval = data.evalReviews
y_eval = data.evalLabels

wordEmbedding = data.wordEmbedding
n_symbols=data.n_symbols


reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=10, mode='auto')
history = model.fit(x_train, y_train, batch_size=config.batchSize, epochs=config.epochs, validation_split=0.3,shuffle=True, callbacks=[reduce_lr])
#验证

scores = model.evaluate(x_eval, y_eval)

#保存模型
yaml_string = model.to_yaml()
with open('../model/textCNN.yml', 'w') as outfile:
    outfile.write( yaml.dump(yaml_string, default_flow_style=True) )
model.save_weights('../model/textCNN.h5')

print('test_loss: %f, accuracy: %f' % (scores[0], scores[1]))
# Out:
# Train on 56592 samples, validate on 24254 samples
# Epoch 1/10
# 56592/56592 [==============================] - 699s 12ms/sample - loss: 0.6978 - accuracy: 0.5045 - val_loss: 0.6924 - val_accuracy: 0.5082
# Epoch 2/10
# 56592/56592 [==============================] - 570s 10ms/sample - loss: 0.6933 - accuracy: 0.5048 - val_loss: 0.6929 - val_accuracy: 0.5012
# Epoch 3/10
# 56592/56592 [==============================] - 571s 10ms/sample - loss: 0.6930 - accuracy: 0.5066 - val_loss: 0.6925 - val_accuracy: 0.5121
# Epoch 4/10
# 56592/56592 [==============================] - 575s 10ms/sample - loss: 0.5045 - accuracy: 0.7346 - val_loss: 0.2329 - val_accuracy: 0.9267
# Epoch 5/10
# 56592/56592 [==============================] - 562s 10ms/sample - loss: 0.2517 - accuracy: 0.9241 - val_loss: 0.2173 - val_accuracy: 0.9325
# Epoch 6/10
# 56592/56592 [==============================] - 609s 11ms/sample - loss: 0.2033 - accuracy: 0.9412 - val_loss: 0.2153 - val_accuracy: 0.9339
# Epoch 7/10
# 52608/56592 [==========================>...] - ETA: 52s - loss: 0.1808 - accuracy: 0.9484

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
